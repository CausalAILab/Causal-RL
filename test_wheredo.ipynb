# %%
# Out:
# Behavioral policy avg discounted return is 5.044074085860702

# %%
# Out:
# Atomic interventional policy avg discounted return is 9.999999999999995

# %%
def policy(u1, u2):
    x1 = u1
    x2 = 1
    return x1, x2
manager = mp.Manager()
results = manager.list()
pcs = [Process(target=worker, kwargs={'policy': policy}) for i in range(TEST_EPI)]
for i in range(TEST_EPI):
    pcs[i].start()
for i in range(TEST_EPI):
    pcs[i].join()
print(f'Atomic interventional policy avg discounted return is {sum(results)/len(results)}')
# Out:
# Atomic interventional policy avg discounted return is 5.013987263499703

# %%
def policy(u1, u2):
    x1 = 1
    x2 = 1
    return x1, x2
manager = mp.Manager()
results = manager.list()
pcs = [Process(target=worker, kwargs={'policy': policy}) for i in range(TEST_EPI)]
for i in range(TEST_EPI):
    pcs[i].start()
for i in range(TEST_EPI):
    pcs[i].join()
print(f'Atomic interventional policy avg discounted return is {sum(results)/len(results)}')
# Out:
# Atomic interventional policy avg discounted return is 4.958845918580794

# %%
def policy(u1, u2):
    x1 = 0
    x2 = 1
    return x1, x2
manager = mp.Manager()
results = manager.list()
pcs = [Process(target=worker, kwargs={'policy': policy}) for i in range(TEST_EPI)]
for i in range(TEST_EPI):
    pcs[i].start()
for i in range(TEST_EPI):
    pcs[i].join()
print(f'Atomic interventional policy avg discounted return is {sum(results)/len(results)}')
# Out:
# Atomic interventional policy avg discounted return is 5.053038301297044

# %%
def policy(u1, u2):
    x1 = 1
    x2 = 0
    return x1, x2
manager = mp.Manager()
results = manager.list()
pcs = [Process(target=worker, kwargs={'policy': policy}) for i in range(TEST_EPI)]
for i in range(TEST_EPI):
    pcs[i].start()
for i in range(TEST_EPI):
    pcs[i].join()
print(f'Atomic interventional policy avg discounted return is {sum(results)/len(results)}')
# Out:
# Atomic interventional policy avg discounted return is 4.926763968430683

# %%
def policy(u1, u2):
    x1 = 0
    x2 = 0
    return x1, x2
manager = mp.Manager()
results = manager.list()
pcs = [Process(target=worker, kwargs={'policy': policy}) for i in range(TEST_EPI)]
for i in range(TEST_EPI):
    pcs[i].start()
for i in range(TEST_EPI):
    pcs[i].join()
print(f'Atomic interventional policy avg discounted return is {sum(results)/len(results)}')
# Out:
# Atomic interventional policy avg discounted return is 4.997736533312605

# %%
def worker(policy=None):
    env = ExamplePCH_9_5_1(max_step=1000)
    _ = env.reset()
    done = False
    reward = 0
    while not done:
        if policy is None:
            x1, x2, y, _, done, _ = env.see()
        else:
            y, _, done, _ = env.do(policy)
        reward = reward * GAMMA + y
    results.append(reward)

manager = mp.Manager()
results = manager.list()
pcs = [Process(target=worker, kwargs={'policy': None}) for i in range(TEST_EPI)]
for i in range(TEST_EPI):
    pcs[i].start()
for i in range(TEST_EPI):
    pcs[i].join()
print(f'Atomic interventional policy avg discounted return is {sum(results)/len(results)}')
# Out:
# Atomic interventional policy avg discounted return is 9.957408287801103

# %%
def policy(u1, u2):
    x1 = 1
    x2 = x1 ^ u2
    return x1, x2
manager = mp.Manager()
results = manager.list()
pcs = [Process(target=worker, kwargs={'policy': policy}) for i in range(TEST_EPI)]
for i in range(TEST_EPI):
    pcs[i].start()
for i in range(TEST_EPI):
    pcs[i].join()
print(f'Atomic interventional policy avg discounted return is {sum(results)/len(results)}')

def policy(u1, u2):
    x1 = 0
    x2 = x1 ^ u2
    return x1, x2
manager = mp.Manager()
results = manager.list()
pcs = [Process(target=worker, kwargs={'policy': policy}) for i in range(TEST_EPI)]
for i in range(TEST_EPI):
    pcs[i].start()
for i in range(TEST_EPI):
    pcs[i].join()
print(f'Atomic interventional policy avg discounted return is {sum(results)/len(results)}')
# Out:
# Atomic interventional policy avg discounted return is 9.999999999999995
# Atomic interventional policy avg discounted return is 9.964828576760196

# %%
def policy(u1, u2):
    x1 = u1
    x2 = 1
    return x1, x2
manager = mp.Manager()
results = manager.list()
pcs = [Process(target=worker, kwargs={'policy': policy}) for i in range(TEST_EPI)]
for i in range(TEST_EPI):
    pcs[i].start()
for i in range(TEST_EPI):
    pcs[i].join()
print(f'Atomic interventional policy avg discounted return is {sum(results)/len(results)}')
# Out:
# Atomic interventional policy avg discounted return is 15.00590839335266
