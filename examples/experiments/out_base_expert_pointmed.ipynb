# %% [markdown]
# # Training base expert on vanilla OGBench environment using BC

# %%
import random
import torch
import os
import math

import matplotlib.pyplot as plt

from collections import defaultdict

from causal_gym import PointMazePCH
from causal_rl.algo.imitation.imitate import *
from causal_rl.algo.imitation.finetune import *
# Out:
# <frozen importlib._bootstrap>:241: RuntimeWarning: Your system is avx2 capable but pygame was not built with support for it. The performance of some of your blits could be adversely affected. Consider enabling compile time detection with environment variables like PYGAME_DETECT_AVX2=1 if you are compiling without cross compilation.
# /home/et2842/miniconda3/envs/causalenv/lib/python3.11/site-packages/pygame/pkgdata.py:25: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_stream, resource_exists

# %%
os.environ['CUDA_VISIBLE_DEVICES'] = '0'
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cuda')

# %%
num_steps = 1000
seed = 0
hidden_dims = {'D'}

random.seed(seed)
torch.manual_seed(seed)

# %%
env = PointMazePCH(num_steps=num_steps, custom_hidden=hidden_dims, expert_mode=True, seed=seed)
train_eps = env.expert.num_eps
train_eps
# Out:
# 1100

# %%
X = {f'X{t}' for t in range(num_steps)}
Y = f'Y{num_steps}'
obs_prefix = env.env.observed_unobserved_vars[0]

# %%
Z_sets = {}
for Xi in X:
    i = int(Xi[1:])
    cond = set()

    for j in range(i+1):
        cond.update({f'{o}{j}' for o in list(set(obs_prefix) - {'X'})})

    for j in range(i):
        cond.add(f'X{j}')

    Z_sets[Xi] = cond

Z_sets['X1']
# Out:
# {'H0', 'H1', 'V0', 'V1', 'X0'}

# %%
records = collect_expert_trajectories(
    env,
    num_episodes=train_eps,
    max_steps=num_steps,
    seed=seed,
    show_progress=True
)
# Out:
# Starting episode 1/1100...
#   Episode 1 ended at step 1000 (terminated: 1.0, truncated: False).
# Starting episode 2/1100...
#   Episode 2 ended at step 1000 (terminated: 1.0, truncated: False).
# Starting episode 3/1100...
#   Episode 3 ended at step 1000 (terminated: 1.0, truncated: False).
# Starting episode 4/1100...
#   Episode 4 ended at step 1000 (terminated: 1.0, truncated: False).
# Starting episode 5/1100...
#   Episode 5 ended at step 1000 (terminated: 1.0, truncated: False).
# Starting episode 6/1100...
#   Episode 6 ended at step 1000 (terminated: 1.0, truncated: False).
# Starting episode 7/1100...
#   Episode 7 ended at step 1000 (terminated: 1.0, truncated: False).
# Starting episode 8/1100...
#   Episode 8 ended at step 1000 (terminated: 1.0, truncated: False).
# Starting episode 9/1100...
#   Episode 9 ended at step 1000 (terminated: 1.0, truncated: False).
# Starting episode 10/1100...
#   Episode 10 ended at step 1000 (terminated: 1.0, truncated: False).
# Starting episode 11/1100...
#   Episode 11 ended at step 1000 (terminated: 1.0, truncated: False).
# Starting episode 12/1100...
#   Episode 12 ended at step 1000 (terminated: 1.0, truncated: False).
# Starting episode 13/1100...
#   Episode 13 ended at step 1000 (terminated: 1.0, truncated: False).
# Starting episode 14/1100...
#   Episode 14 ended at step 1000 (terminated: 1.0, truncated: False).
# Starting episode 15/1100...
#   Episode 15 ended at step 1000 (terminated: 1.0, truncated: False).
# Starting episode 16/1100...
#   Episode 16 ended at step 1000 (terminated: 1.0, truncated: False).
# Starting episode 17/1100...
#   Episode 17 ended at step 1000 (terminated: 1.0, truncated: False).
# Starting episode 18/1100...
#   Episode 18 ended at step 1000 (terminated: 1.0, truncated: False).
# Starting episode 19/1100...
#   Episode 19 ended at step 1000 (terminated: 1.0, truncated: False).
# Starting episode 20/1100...
#   Episode 20 ended at step 1000 (terminated: 1.0, truncated: False).
# Starting episode 21/1100...
#   Episode 21 ended at step 1000 (terminated: 1.0, truncated: False).
# Starting episode 22/1100...
#   Episode 22 ended at step 1000 (terminated: 1.0, truncated: False).
# Starting episode 23/1100...
#   Episode 23 ended at step 1000 (terminated: 1.0, truncated: False).
# Starting episode 24/1100...
#   Episode 24 ended at step 1000 (terminated: 1.0, truncated: False).
# Starting episode 25/1100...
#   Episode 25 ended at step 1000 (terminated: 1.0, truncated: False).
# Starting episode 26/1100...
#   Episode 26 ended at step 1000 (terminated: 1.0, truncated: False).
# Starting episode 27/1100...
#   Episode 27 ended at step 1000 (terminated: 1.0, truncated: False).
# Starting episode 28/1100...
#   Episode 28 ended at step 1000 (terminated: 1.0, truncated: False).
# Starting episode 29/1100...
#   Episode 29 ended at step 1000 (terminated: 1.0, truncated: False).
# Starting episode 30/1100...
#   Episode 30 ended at step 1000 (terminated: 1.0, truncated: False).
# Starting episode 31/1100...
#   Episode 31 ended at step 1000 (terminated: 1.0, truncated: False).
# Starting episode 32/1100...
#   Episode 32 ended at step 1000 (terminated: 1.0, truncated: False).
# Starting episode 33/1100...
#   Episode 33 ended at step 1000 (terminated: 1.0, truncated: False).
# Starting episode 34/1100...
#   Episode 34 ended at step 1000 (terminated: 1.0, truncated: False).
# Starting episode 35/1100...
#   Episode 35 ended at step 1000 (terminated: 1.0, truncated: False).
# Starting episode 36/1100...
#   Episode 36 ended at step 1000 (terminated: 1.0, truncated: False).
# Starting episode 37/1100...
#   Episode 37 ended at step 1000 (terminated: 1.0, truncated: False).
# Starting episode 38/1100...
#   Episode 38 ended at step 1000 (terminated: 1.0, truncated: False).
# Starting episode 39/1100...
#   Episode 39 ended at step 1000 (terminated: 1.0, truncated: False).
# Starting episode 40/1100...
#   Episode 40 ended at step 1000 (terminated: 1.0, truncated: False).
# Starting episode 41/1100...
#   Episode 41 ended at step 1000 (terminated: 1.0, truncated: False).
# Starting episode 42/1100...
#   Episode 42 ended at step 1000 (terminated: 1.0, truncated: False).
# Starting episode 43/1100...
#   Episode 43 ended at step 1000 (terminated: 1.0, truncated: False).
# Starting episode 44/1100...
#   Episode 44 ended at step 1000 (terminated: 1.0, truncated: False).
# Starting episode 45/1100...
#   Episode 45 ended at step 1000 (terminated: 1.0, truncated: False).
# Starting episode 46/1100...
#   Episode 46 ended at step 1000 (terminated: 1.0, truncated: False).
# Starting episode 47/1100...
#   Episode 47 ended at step 1000 (terminated: 1.0, truncated: False).
# Starting episode 48/1100...
#   Episode 48 ended at step 1000 (terminated: 1.0, truncated: False).
# Starting episode 49/1100...
#   Episode 49 ended at step 1000 (terminated: 1.0, truncated: False).
# Starting episode 50/1100...
#   Episode 50 ended at step 1000 (terminated: 1.0, truncated: False).
# Starting episode 51/1100...
#   Episode 51 ended at step 1000 (terminated: 1.0, truncated: False).
# Starting episode 52/1100...
#   Episode 52 ended at step 1000 (terminated: 1.0, truncated: False).
# Starting episode 53/1100...
#   Episode 53 ended at step 1000 (terminated: 1.0, truncated: False).
# Starting episode
ended at step 1000 (terminated: 1.0, truncated: False).
# Starting episode 1050/1100...
#   Episode 1050 ended at step 1000 (terminated: 1.0, truncated: False).
# Starting episode 1051/1100...
#   Episode 1051 ended at step 1000 (terminated: 1.0, truncated: False).
# Starting episode 1052/1100...
#   Episode 1052 ended at step 1000 (terminated: 1.0, truncated: False).
# Starting episode 1053/1100...
#   Episode 1053 ended at step 1000 (terminated: 1.0, truncated: False).
# Starting episode 1054/1100...
#   Episode 1054 ended at step 1000 (terminated: 1.0, truncated: False).
# Starting episode 1055/1100...
#   Episode 1055 ended at step 1000 (terminated: 1.0, truncated: False).
# Starting episode 1056/1100...
#   Episode 1056 ended at step 1000 (terminated: 1.0, truncated: False).
# Starting episode 1057/1100...
#   Episode 1057 ended at step 1000 (terminated: 1.0, truncated: False).
# Starting episode 1058/1100...
#   Episode 1058 ended at step 1000 (terminated: 1.0, truncated: False).
# Starting episode 1059/1100...
#   Episode 1059 ended at step 1000 (terminated: 1.0, truncated: False).
# Starting episode 1060/1100...
#   Episode 1060 ended at step 1000 (terminated: 1.0, truncated: False).
# Starting episode 1061/1100...
#   Episode 1061 ended at step 1000 (terminated: 1.0, truncated: False).
# Starting episode 1062/1100...
#   Episode 1062 ended at step 1000 (terminated: 1.0, truncated: False).
# Starting episode 1063/1100...
#   Episode 1063 ended at step 1000 (terminated: 1.0, truncated: False).
# Starting episode 1064/1100...
#   Episode 1064 ended at step 1000 (terminated: 1.0, truncated: False).
# Starting episode 1065/1100...
#   Episode 1065 ended at step 1000 (terminated: 1.0, truncated: False).
# Starting episode 1066/1100...
#   Episode 1066 ended at step 1000 (terminated: 1.0, truncated: False).
# Starting episode 1067/1100...
#   Episode 1067 ended at step 1000 (terminated: 1.0, truncated: False).
# Starting episode 1068/1100...
#   Episode 1068 ended at step 1000 (terminated: 1.0, truncated: False).
# Starting episode 1069/1100...
#   Episode 1069 ended at step 1000 (terminated: 1.0, truncated: False).
# Starting episode 1070/1100...
#   Episode 1070 ended at step 1000 (terminated: 1.0, truncated: False).
# Starting episode 1071/1100...
#   Episode 1071 ended at step 1000 (terminated: 1.0, truncated: False).
# Starting episode 1072/1100...
#   Episode 1072 ended at step 1000 (terminated: 1.0, truncated: False).
# Starting episode 1073/1100...
#   Episode 1073 ended at step 1000 (terminated: 1.0, truncated: False).
# Starting episode 1074/1100...
#   Episode 1074 ended at step 1000 (terminated: 1.0, truncated: False).
# Starting episode 1075/1100...
#   Episode 1075 ended at step 1000 (terminated: 1.0, truncated: False).
# Starting episode 1076/1100...
#   Episode 1076 ended at step 1000 (terminated: 1.0, truncated: False).
# Starting episode 1077/1100...
#   Episode 1077 ended at step 1000 (terminated: 1.0, truncated: False).
# Starting episode 1078/1100...
#   Episode 1078 ended at step 1000 (terminated: 1.0, truncated: False).
# Starting episode 1079/1100...
#   Episode 1079 ended at step 1000 (terminated: 1.0, truncated: False).
# Starting episode 1080/1100...
#   Episode 1080 ended at step 1000 (terminated: 1.0, truncated: False).
# Starting episode 1081/1100...
#   Episode 1081 ended at step 1000 (terminated: 1.0, truncated: False).
# Starting episode 1082/1100...
#   Episode 1082 ended at step 1000 (terminated: 1.0, truncated: False).
# Starting episode 1083/1100...
#   Episode 1083 ended at step 1000 (terminated: 1.0, truncated: False).
# Starting episode 1084/1100...
#   Episode 1084 ended at step 1000 (terminated: 1.0, truncated: False).
# Starting episode 1085/1100...
#   Episode 1085 ended at step 1000 (terminated: 1.0, truncated: False).
# Starting episode 1086/1100...
#   Episode 1086 ended at step 1000 (terminated: 1.0, truncated: False).
# Starting episode 1087/1100...
#   Episode 1087 ended at step 1000 (terminated: 1.0, truncated: False).
# Starting episode 1088/1100...
#   Episode 1088 ended at step 1000 (terminated: 1.0, truncated: False).
# Starting episode 1089/1100...
#   Episode 1089 ended at step 1000 (terminated: 1.0, truncated: False).
# Starting episode 1090/1100...
#   Episode 1090 ended at step 1000 (terminated: 1.0, truncated: False).
# Starting episode 1091/1100...
#   Episode 1091 ended at step 1000 (terminated: 1.0, truncated: False).
# Starting episode 1092/1100...
#   Episode 1092 ended at step 1000 (terminated: 1.0, truncated: False).
# Starting episode 1093/1100...
#   Episode 1093 ended at step 1000 (terminated: 1.0, truncated: False).
# Starting episode 1094/1100...
#   Episode 1094 ended at step 1000 (terminated: 1.0, truncated: False).
# Starting episode 1095/1100...
#   Episode 1095 ended at step 1000 (terminated: 1.0, truncated: False).
# Starting episode 1096/1100...
#   Episode 1096 ended at step 1000 (terminated: 1.0, truncated: False).
# Starting episode 1097/1100...
#   Episode 1097 ended at step 1000 (terminated: 1.0, truncated: False).
# Starting episode 1098/1100...
#   Episode 1098 ended at step 1000 (terminated: 1.0, truncated: False).
# Starting episode 1099/1100...
#   Episode 1099 ended at step 1000 (terminated: 1.0, truncated: False).
# Starting episode 1100/1100...
#   Episode 1100 ended at step 1000 (terminated: 1.0, truncated: False).
# Finished collecting expert trajectories.

# %%
hidden_size = 256
lr = 3e-4
batch_size = 2048
patience = 15
lookback = 1
num_blocks = 4
epochs = 50 # 100
dropout = 0.0

dims = {
    'V': 1,
    'H': 1,
    # 'D': 1,
    'X': 2
}

# %%
model, slots, Z_trim = train_single_policy_long_horizon(
    records,
    Z_sets,
    dims=dims,
    epochs=epochs,
    include_vars=obs_prefix,
    lookback=lookback,
    continuous=True,
    num_actions = env.action_space.shape[0],
    hidden_dim=hidden_size,
    num_blocks=num_blocks,
    dropout=dropout,
    lr=lr,
    batch_size=batch_size,
    patience=patience,
    device=device,
    seed=seed,
    action_bounds=(env.action_space.low, env.action_space.high)
)

policy = shared_policy_fn_long_horizon(model, slots, Z_trim, continuous=True, device=device)
policies = make_shared_policy_dict(policy)
# Out:
# [LongHorizon] Epoch 1: train loss = 0.150744, val loss = 0.133787.
# [LongHorizon] Epoch 2: train loss = 0.130334, val loss = 0.127612.
# [LongHorizon] Epoch 3: train loss = 0.123421, val loss = 0.120666.
# [LongHorizon] Epoch 4: train loss = 0.120209, val loss = 0.119004.
# [LongHorizon] Epoch 5: train loss = 0.118549, val loss = 0.117044.
# [LongHorizon] Epoch 6: train loss = 0.117395, val loss = 0.116517.
# [LongHorizon] Epoch 7: train loss = 0.116067, val loss = 0.115042.
# [LongHorizon] Epoch 8: train loss = 0.115017, val loss = 0.114607.
# [LongHorizon] Epoch 9: train loss = 0.114082, val loss = 0.113256.
# [LongHorizon] Epoch 10: train loss = 0.113322, val loss = 0.113351.
# [LongHorizon] Epoch 11: train loss = 0.112526, val loss = 0.111956.
# [LongHorizon] Epoch 12: train loss = 0.111924, val loss = 0.111340.
# [LongHorizon] Epoch 13: train loss = 0.111433, val loss = 0.110840.
# [LongHorizon] Epoch 14: train loss = 0.110877, val loss = 0.112167.
# [LongHorizon] Epoch 15: train loss = 0.110332, val loss = 0.110332.
# [LongHorizon] Epoch 16: train loss = 0.109721, val loss = 0.109313.
# [LongHorizon] Epoch 17: train loss = 0.109448, val loss = 0.109645.
# [LongHorizon] Epoch 18: train loss = 0.108936, val loss = 0.109601.
# [LongHorizon] Epoch 19: train loss = 0.108614, val loss = 0.108425.
# [LongHorizon] Epoch 20: train loss = 0.108619, val loss = 0.108100.
# [LongHorizon] Epoch 21: train loss = 0.108015, val loss = 0.108723.
# [LongHorizon] Epoch 22: train loss = 0.107502, val loss = 0.107474.
# [LongHorizon] Epoch 23: train loss = 0.107441, val loss = 0.108601.
# [LongHorizon] Epoch 24: train loss = 0.107225, val loss = 0.109196.
# [LongHorizon] Epoch 25: train loss = 0.107043, val loss = 0.106746.
# [LongHorizon] Epoch 26: train loss = 0.106853, val loss = 0.108338.
# [LongHorizon] Epoch 27: train loss = 0.106578, val loss = 0.106558.
# [LongHorizon] Epoch 28: train loss = 0.106487, val loss = 0.106574.
# [LongHorizon] Epoch 29: train loss = 0.106482, val loss = 0.107054.
# [LongHorizon] Epoch 30: train loss = 0.106284, val loss = 0.107309.
# [LongHorizon] Epoch 31: train loss = 0.106099, val loss = 0.106757.
# [LongHorizon] Epoch 32: train loss = 0.105875, val loss = 0.108137.
# [LongHorizon] Epoch 33: train loss = 0.105749, val loss = 0.107058.
# [LongHorizon] Epoch 34: train loss = 0.105712, val loss = 0.107013.
# [LongHorizon] Epoch 35: train loss = 0.105721, val loss = 0.105659.
# [LongHorizon] Epoch 36: train loss = 0.105366, val loss = 0.105728.
# [LongHorizon] Epoch 37: train loss = 0.105250, val loss = 0.104945.
# [LongHorizon] Epoch 38: train loss = 0.105048, val loss = 0.104828.
# [LongHorizon] Epoch 39: train loss = 0.105111, val loss = 0.104659.
# [LongHorizon] Epoch 40: train loss = 0.104959, val loss = 0.105480.
# [LongHorizon] Epoch 41: train loss = 0.104843, val loss = 0.104547.
# [LongHorizon] Epoch 42: train loss = 0.104879, val loss = 0.105491.
# [LongHorizon] Epoch 43: train loss = 0.104583, val loss = 0.104587.
# [LongHorizon] Epoch 44: train loss = 0.104432, val loss = 0.105787.
# [LongHorizon] Epoch 45: train loss = 0.104665, val loss = 0.103934.
# [LongHorizon] Epoch 46: train loss = 0.104301, val loss = 0.103623.
# [LongHorizon] Epoch 47: train loss = 0.104396, val loss = 0.104295.
# [LongHorizon] Epoch 48: train loss = 0.104165, val loss = 0.104234.
# [LongHorizon] Epoch 49: train loss = 0.104149, val loss = 0.104243.
# [LongHorizon] Epoch 50: train loss = 0.104060, val loss = 0.104832.

# %%
expert_episode_rewards = defaultdict(float)
for rec in records:
    ep = rec['episode']
    expert_episode_rewards[ep] += float(rec['reward'])

num_eps = len(expert_episode_rewards)
expert_rewards = [expert_episode_rewards[e] for e in range(num_eps)]

num_eval_eps = 20

policy_records = collect_imitator_trajectories(
    env=env,
    policies=policies,
    num_episodes=num_eval_eps,
    max_steps=num_steps,
    hidden_dims=hidden_dims,
    show_progress=True
)

policy_episode_rewards = defaultdict(float)
for rec in policy_records:
    ep = rec['episode']
    policy_episode_rewards[ep] += float(rec['reward'])

policy_rewards = [policy_episode_rewards[e] for e in range(num_eval_eps)]

sum(expert_rewards)/num_eps, sum(policy_rewards)/num_eval_eps
# Out:
# Starting episode 1/20...
# Warning: Expert trajectories exhausted. If this is a reset to begin do(), ignore this message.
#   Episode 1 ended at step 1000 (terminated: False, truncated: True).
# Starting episode 2/20...
#   Episode 2 ended at step 1000 (terminated: False, truncated: True).
# Starting episode 3/20...
#   Episode 3 ended at step 1000 (terminated: False, truncated: True).
# Starting episode 4/20...
#   Episode 4 ended at step 1000 (terminated: False, truncated: True).
# Starting episode 5/20...
#   Episode 5 ended at step 1000 (terminated: False, truncated: True).
# Starting episode 6/20...
#   Episode 6 ended at step 1000 (terminated: False, truncated: True).
# Starting episode 7/20...
#   Episode 7 ended at step 1000 (terminated: False, truncated: True).
# Starting episode 8/20...
#   Episode 8 ended at step 1000 (terminated: False, truncated: True).
# Starting episode 9/20...
#   Episode 9 ended at step 1000 (terminated: False, truncated: True).
# Starting episode 10/20...
#   Episode 10 ended at step 1000 (terminated: False, truncated: True).
# Starting episode 11/20...
#   Episode 11 ended at step 1000 (terminated: False, truncated: True).
# Starting episode 12/20...
#   Episode 12 ended at step 1000 (terminated: False, truncated: True).
# Starting episode 13/20...
#   Episode 13 ended at step 1000 (terminated: False, truncated: True).
# Starting episode 14/20...
#   Episode 14 ended at step 1000 (terminated: False, truncated: True).
# Starting episode 15/20...
#   Episode 15 ended at step 1000 (terminated: False, truncated: True).
# Starting episode 16/20...
#   Episode 16 ended at step 1000 (terminated: False, truncated: True).
# Starting episode 17/20...
#   Episode 17 ended at step 1000 (terminated: False, truncated: True).
# Starting episode 18/20...
#   Episode 18 ended at step 1000 (terminated: False, truncated: True).
# Starting episode 19/20...
#   Episode 19 ended at step 1000 (terminated: False, truncated: True).
# Starting episode 20/20...
#   Episode 20 ended at step 1000 (terminated: False, truncated: True).
# Finished collecting imitator trajectories.
# (-937.8136363636364, -9.077937704082249)

# %%
# save model for fine-tuning
import os
import torch

SAVE_DIR = '/home/et2842/causal/causalrl/models'
os.makedirs(SAVE_DIR, exist_ok=True)
MODEL_PATH = os.path.join(SAVE_DIR, 'pointmaze_medium_expert.pt')

checkpoint = {
    "state_dict": model.state_dict(),
    "slots": slots,
    "Z_trim": Z_trim,
    "dims": dims,
    "lookback": lookback,
    "continuous": True,
    "num_actions": env.action_space.shape[0],
    "hidden_dim": hidden_size,
    "num_blocks": num_blocks,
    "dropout": 0.0,
    "layernorm": True,
    "final_tanh": True,
    "action_bounds_low": env.action_space.low,
    "action_bounds_high": env.action_space.high,
    "input_dim": int(model.hidden.in_features),
}

torch.save(checkpoint, MODEL_PATH)
print("Saved expert to:", MODEL_PATH)
# Out:
# Saved expert to: /home/et2842/causal/causalrl/models/pointmaze_medium_expert.pt
