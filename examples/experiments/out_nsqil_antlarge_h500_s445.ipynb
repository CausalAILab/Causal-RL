# %%
import random
import copy
import torch
import pickle
import os
import numpy as np
import matplotlib.pyplot as plt

from collections import defaultdict

from causal_gym import AntMazePCH
from causal_rl.algo.imitation.imitate import *
from causal_rl.algo.imitation.finetune import *
from causal_rl.algo.imitation.gail.core_net import ContinuousActor
from causal_rl.algo.imitation.gail.causal_gail import *
from causal_rl.algo.imitation.sqil.core_net import SACQNetwork
from causal_rl.algo.imitation.sqil.causal_sqil import (
    SQILReplayBuffer, initialize_expert_buffer,
    rollout_sqil_episode, sac_update, soft_update,
    evaluate_sqil_policy,
)
# Out:
# <frozen importlib._bootstrap>:241: RuntimeWarning: Your system is avx2 capable but pygame was not built with support for it. The performance of some of your blits could be adversely affected. Consider enabling compile time detection with environment variables like PYGAME_DETECT_AVX2=1 if you are compiling without cross compilation.
# /home/et2842/miniconda3/envs/causalenv/lib/python3.11/site-packages/pygame/pkgdata.py:25: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_stream, resource_exists

# %%
os.environ['CUDA_VISIBLE_DEVICES'] = '6'
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cuda')

# %%
num_steps = 500
seed = 445
lookback = 10
hidden_dims = {'O'}

random.seed(seed)
torch.manual_seed(seed)

# %%
# for training: regular W, O hidden
train_env = AntMazePCH(env_id='antmaze-large-navigate-singletask-task1-v0', num_steps=num_steps, expert_mode=True, custom_hidden=hidden_dims, seed=seed)

# for eval: corrupted W, O hidden
eval_env = AntMazePCH(env_id='antmaze-large-navigate-singletask-task1-v0', num_steps=num_steps, expert_mode=False, seed=seed)

# %% [markdown]
# ## Causal Graph Analysis

# %%
# to save time; conceptually the same
small_steps = lookback + 1
small_env = AntMazePCH(num_steps=small_steps, seed=seed)
G = parse_graph(small_env.get_graph)
X_small = {f'X{t}' for t in range(small_steps)}
Y = f'Y{small_steps}'

X = {f'X{t}' for t in range(num_steps)}
obs_prefix = train_env.env.observed_unobserved_vars[0]

# %%
naive_Z_sets = {}
for Xi in X:
    i = int(Xi[1:])
    cond = set()

    for j in range(i+1):
        cond.update({f'{o}{j}' for o in list(set(obs_prefix) - {'X'})})

    for j in range(i):
        cond.add(f'X{j}')
    naive_Z_sets[Xi] = cond

naive_Z_sets['X1']
# Out:
# {'A0', 'A1', 'J0', 'J1', 'L0', 'L1', 'P0', 'P1', 'T0', 'T1', 'W0', 'W1', 'X0'}

# %% [markdown]
# ## Expert Trajectories

# %%
with open('/home/et2842/causal/expert_traj_antlarge_h500.pkl', 'rb') as f:
    records = pickle.load(f)

print(f'loaded {len(records)} trajectories')
# Out:
# loaded 249822 trajectories

# %%
dims = {
    'P': 3,
    # 'O': 4,
    'A': 8,
    'L': 3,
    'T': 3,
    'J': 8,
    'W': 2,
    'X': 8,
}

# %%
sample_obs = records[0]['obs']

# Trim Z-sets to the lookback window
naive_Z_trim = trim_Z_sets(naive_Z_sets, lookback=lookback)

# Build windowed encoders that depend on relative lags
naive_encode, naive_z_dim, naive_slots = build_windowed_z_encoder(
    naive_Z_trim,
    dims=dims,
    lookback=lookback,
)

encode = naive_encode
z_dim = naive_z_dim
Z_trim = naive_Z_trim
naive_z_dim
# Out:
# 377

# %% [markdown]
# ## Hyperparameters

# %%
# Shared SAC hyperparameters
total_timesteps = 2_000_000
batch_size = 256
gamma = 0.99
tau = 0.005
actor_lr = 3e-4
critic_lr = 3e-4
alpha_lr = 3e-4
hidden_dim = 256
buffer_capacity = 1_000_000
expert_capacity_ratio = 0.5
start_steps = 5_000
log_every = 50
eval_episodes = 10
max_grad_norm = 1.0
max_updates_per_episode = 1000

# Actor architecture (match GAIL)
num_blocks_actor = 3
dropout_actor = 0.05
layernorm_actor = True

# Environment action space
action_dim = train_env.env.action_space.shape[0]
action_low = float(train_env.env.action_space.low.min())
action_high = float(train_env.env.action_space.high.max())
target_entropy = -float(action_dim)

# %% [markdown]
# ## Network Initialization

# %%
actor = ContinuousActor(
    num_inputs=z_dim, num_outputs=action_dim,
    hidden_size=hidden_dim, std=0.0,
    action_low=action_low, action_high=action_high,
    num_blocks=num_blocks_actor, dropout=dropout_actor, layernorm=layernorm_actor,
).to(device)

q1 = SACQNetwork(z_dim, action_dim, hidden_dim).to(device)
q2 = SACQNetwork(z_dim, action_dim, hidden_dim).to(device)
tq1 = copy.deepcopy(q1)
tq2 = copy.deepcopy(q2)
for p in tq1.parameters(): p.requires_grad = False
for p in tq2.parameters(): p.requires_grad = False

actor_optim = torch.optim.Adam(actor.parameters(), lr=actor_lr)
q1_optim = torch.optim.Adam(q1.parameters(), lr=critic_lr)
q2_optim = torch.optim.Adam(q2.parameters(), lr=critic_lr)

# Automatic entropy tuning
log_alpha = torch.zeros(1, requires_grad=True, device=device)
alpha_optim = torch.optim.Adam([log_alpha], lr=alpha_lr)

buffer = SQILReplayBuffer(buffer_capacity, expert_capacity_ratio)
initialize_expert_buffer(records, encode, buffer, device)
# Out:
# Expert buffer: 249822 transitions from 500 episodes

# %% [markdown]
# ## Training

# %%
best_eval = -float('inf')
best_state_dict = copy.deepcopy(actor.state_dict())

ts = 0
ep = 0
logs = []

while ts < total_timesteps:
    ep_data = rollout_sqil_episode(
        train_env, actor, buffer, encode,
        num_steps, device, deterministic=False, seed=seed + 10000 + ep
    )
    ts += ep_data['episode_length']
    ep += 1

    if ts > start_steps and len(buffer.policy_buffer) >= batch_size:
        n_updates = min(ep_data['episode_length'], max_updates_per_episode)
        for _ in range(n_updates):
            sac_update(
                q1, q2, tq1, tq2, actor, log_alpha, target_entropy,
                q1_optim, q2_optim, actor_optim, alpha_optim,
                buffer, batch_size, gamma, device, max_grad_norm,
            )
            soft_update(q1, tq1, tau)
            soft_update(q2, tq2, tau)

            # Alpha clamping (stability fix, matches IQ-Learn)
            with torch.no_grad():
                log_alpha.clamp_(min=np.log(0.001), max=np.log(0.1))

    if ep % log_every == 0:
        eval_ret = evaluate_sqil_policy(
            train_env, actor, encode, num_steps, device, eval_episodes, seed=42
        )
        logs.append({
            'episode': ep, 'timesteps': ts,
            'eval_return': eval_ret, 'train_return': ep_data['episode_return'],
            'alpha': log_alpha.exp().item(),
        })
        print(
            f"[Naive SQIL ep {ep}] "
            f"ts={ts}, eval={eval_ret:.2f}, "
            f"train={ep_data['episode_return']:.2f}, "
            f"alpha={log_alpha.exp().item():.4f}"
        )

        # Best checkpoint tracking
        if eval_ret > best_eval:
            best_eval = eval_ret
            best_state_dict = copy.deepcopy(actor.state_dict())

# Restore best
actor.load_state_dict(best_state_dict)
print(f"Restored best checkpoint with eval={best_eval:.2f}")
# Out:
# [Naive SQIL ep 50] ts=25000, eval=-180.51, train=-373.69, alpha=0.0172
# [Naive SQIL ep 100] ts=50000, eval=-156.72, train=-228.81, alpha=0.0191
# [Naive SQIL ep 150] ts=75000, eval=-140.43, train=-214.69, alpha=0.0177
# [Naive SQIL ep 200] ts=100000, eval=-133.43, train=-43.34, alpha=0.0195
# [Naive SQIL ep 250] ts=125000, eval=-138.87, train=-223.38, alpha=0.0201
# [Naive SQIL ep 300] ts=149961, eval=-130.00, train=-107.45, alpha=0.0205
# [Naive SQIL ep 350] ts=174961, eval=-143.66, train=-150.47, alpha=0.0215
# [Naive SQIL ep 400] ts=199961, eval=-143.77, train=-170.96, alpha=0.0224
# [Naive SQIL ep 450] ts=224961, eval=-132.01, train=-50.96, alpha=0.0239
# [Naive SQIL ep 500] ts=249907, eval=-127.20, train=-259.86, alpha=0.0257
# [Naive SQIL ep 550] ts=274907, eval=-132.54, train=-295.93, alpha=0.0257
# [Naive SQIL ep 600] ts=299907, eval=-144.32, train=-119.21, alpha=0.0259
# [Naive SQIL ep 650] ts=324907, eval=-140.91, train=-157.83, alpha=0.0267
# [Naive SQIL ep 700] ts=349907, eval=-149.43, train=-233.76, alpha=0.0270
# [Naive SQIL ep 750] ts=374907, eval=-142.05, train=-255.59, alpha=0.0279
# [Naive SQIL ep 800] ts=399907, eval=-140.14, train=-171.51, alpha=0.0292
# [Naive SQIL ep 850] ts=424907, eval=-147.06, train=-161.87, alpha=0.0287
# [Naive SQIL ep 900] ts=449900, eval=-132.61, train=-96.25, alpha=0.0294
# [Naive SQIL ep 950] ts=474900, eval=-132.87, train=-99.24, alpha=0.0299
# [Naive SQIL ep 1000] ts=499900, eval=-133.53, train=-210.31, alpha=0.0297
# [Naive SQIL ep 1050] ts=524900, eval=-144.27, train=-251.48, alpha=0.0306
# [Naive SQIL ep 1100] ts=549900, eval=-136.82, train=-330.38, alpha=0.0320
# [Naive SQIL ep 1150] ts=574900, eval=-141.37, train=-427.55, alpha=0.0324
# [Naive SQIL ep 1200] ts=599900, eval=-135.46, train=-42.09, alpha=0.0339
# [Naive SQIL ep 1250] ts=624900, eval=-132.64, train=-227.56, alpha=0.0348
# [Naive SQIL ep 1300] ts=649900, eval=-134.66, train=-163.12, alpha=0.0351
# [Naive SQIL ep 1350] ts=674900, eval=-150.60, train=-268.77, alpha=0.0357
# [Naive SQIL ep 1400] ts=699900, eval=-149.33, train=-124.65, alpha=0.0357
# [Naive SQIL ep 1450] ts=724900, eval=-159.35, train=-159.06, alpha=0.0357
# [Naive SQIL ep 1500] ts=749900, eval=-171.46, train=-299.30, alpha=0.0350
# [Naive SQIL ep 1550] ts=774900, eval=-183.50, train=-407.43, alpha=0.0358
# [Naive SQIL ep 1600] ts=799900, eval=-189.71, train=-282.98, alpha=0.0354
# [Naive SQIL ep 1650] ts=824900, eval=-190.56, train=-214.21, alpha=0.0383
# [Naive SQIL ep 1700] ts=849900, eval=-190.15, train=-210.30, alpha=0.0370
# [Naive SQIL ep 1750] ts=874900, eval=-177.85, train=-139.36, alpha=0.0335
# [Naive SQIL ep 1800] ts=899900, eval=-156.62, train=-262.72, alpha=0.0295
# [Naive SQIL ep 1850] ts=924900, eval=-143.51, train=-117.30, alpha=0.0272
# [Naive SQIL ep 1900] ts=949900, eval=-189.66, train=-259.32, alpha=0.0238
# [Naive SQIL ep 1950] ts=974900, eval=-144.64, train=-42.31, alpha=0.0238
# [Naive SQIL ep 2000] ts=999900, eval=-140.57, train=-125.55, alpha=0.0239
# [Naive SQIL ep 2050] ts=1024900, eval=-136.06, train=-199.68, alpha=0.0251
# [Naive SQIL ep 2100] ts=1049900, eval=-162.18, train=-160.13, alpha=0.0229
# [Naive SQIL ep 2150] ts=1074900, eval=-131.97, train=-88.00, alpha=0.0227
# [Naive SQIL ep 2200] ts=1099900, eval=-154.11, train=-276.76, alpha=0.0225
# [Naive SQIL ep 2250] ts=1124900, eval=-135.73, train=-146.11, alpha=0.0221
# [Naive SQIL ep 2300] ts=1149900, eval=-136.76, train=-22.21, alpha=0.0222
# [Naive SQIL ep 2350] ts=1174900, eval=-135.32, train=-74.07, alpha=0.0238
# [Naive SQIL ep 2400] ts=1199900, eval=-136.22, train=-287.16, alpha=0.0238
# [Naive SQIL ep 2450] ts=1224900, eval=-136.33, train=-79.79, alpha=0.0243
# [Naive SQIL ep 2500] ts=1249900, eval=-131.93, train=-208.15, alpha=0.0254
# [Naive SQIL ep 2550] ts=1274900, eval=-142.33, train=-134.74, alpha=0.0257
# [Naive SQIL ep 2600] ts=1299900, eval=-124.55, train=-160.02, alpha=0.0262
# [Naive SQIL ep 2650] ts=1324900, eval=-135.73, train=-241.19, alpha=0.0269
# [Naive SQIL ep 2700] ts=1349900, eval=-139.94, train=-263.63, alpha=0.0279
# [Naive SQIL ep 2750] ts=1374900, eval=-145.65, train=-83.27, alpha=0.0295
# [Naive SQIL ep 2800] ts=1399900, eval=-145.56, train=-248.04, alpha=0.0297
# [Naive SQIL ep 2850] ts=1424900, eval=-145.62, train=-252.98, alpha=0.0309
# [Naive SQIL ep 2900] ts=1449900, eval=-174.32, train=-161.91, alpha=0.0326
# [Naive SQIL ep 2950] ts=1474900, eval=-190.56, train=-210.86, alpha=0.0324
# [Naive SQIL ep 3000] ts=1499900, eval=-190.75, train=-431.09, alpha=0.0336
# [Naive SQIL ep 3050] ts=1524900, eval=-189.32, train=-482.75, alpha=0.0344
# [Naive SQIL ep 3100] ts=1549900, eval=-188.50, train=-246.66, alpha=0.0362
# [Naive SQIL ep 3150] ts=1574900, eval=-187.71, train=-216.59, alpha=0.0374
# [Naive SQIL ep 3200] ts=1599900, eval=-188.92, train=-266.06, alpha=0.0409
# [Naive SQIL ep 3250] ts=1624900, eval=-189.93, train=-422.22, alpha=0.0423
# [Naive SQIL ep 3300] ts=1649900, eval=-176.13, train=-166.37, alpha=0.0420
# [Naive SQIL ep 3350] ts=1674900, eval=-172.88, train=-196.79, alpha=0.0351
# [Naive SQIL ep 3400] ts=1699900, eval=-155.49, train=-69.86, alpha=0.0287
# [Naive SQIL ep 3450] ts=1724900, eval=-130.74, train=-268.64, alpha=0.0262
# [Naive SQIL ep 3500] ts=1749900, eval=-135.14, train=-232.18, alpha=0.0239
# [Naive SQIL ep 3550] ts=1774900, eval=-136.94, train=-58.50, alpha=0.0240
# [Naive SQIL ep 3600] ts=1799900, eval=-142.19, train=-300.07, alpha=0.0241
# [Naive SQIL ep 3650] ts=1824900, eval=-127.51, train=-179.13, alpha=0.0235
# [Naive SQIL ep 3700] ts=1849900, eval=-137.08, train=-101.05, alpha=0.0234
# [Naive SQIL ep 3750] ts=1874900, eval=-133.99, train=-234.57, alpha=0.0225
# [Naive SQIL ep 3800] ts=1899900, eval=-126.20, train=-181.49, alpha=0.0228
# [Naive SQIL ep 3850] ts=1924900, eval=-133.20, train=-92.98, alpha=0.0231
# [Naive SQIL ep 3900] ts=1949900, eval=-141.24, train=-48.75, alpha=0.0229
# [Naive SQIL ep 3950] ts=1974900, eval=-131.71, train=-238.37, alpha=0.0236
# [Naive SQIL ep 4000] ts=1999900, eval=-155.69, train=-215.03, alpha=0.0250
# Restored best checkpoint with eval=-124.55

# %% [markdown]
# ## Evaluation

# %%
naive_sqil_policy = make_gail_policy(actor, encode, device=device, deterministic=True)
naive_sqil_policies = make_shared_policy_dict(naive_sqil_policy)

# %%
num_eval_eps = 1000
naive_sqil_returns = collect_imitator_trajectories(
    env=eval_env,
    policies=naive_sqil_policies,
    num_episodes=num_eval_eps,
    max_steps=num_steps,
    hidden_dims=hidden_dims,
    show_progress=True,
    seed=seed + 90210,
)

len(naive_sqil_returns)
# Out:
# Starting episode 1/1000...
#   Episode 1 ended at step 500 (terminated: False, truncated: True).
# Starting episode 2/1000...
#   Episode 2 ended at step 500 (terminated: False, truncated: True).
# Starting episode 3/1000...
#   Episode 3 ended at step 500 (terminated: False, truncated: True).
# Starting episode 4/1000...
#   Episode 4 ended at step 500 (terminated: False, truncated: True).
# Starting episode 5/1000...
#   Episode 5 ended at step 500 (terminated: False, truncated: True).
# Starting episode 6/1000...
#   Episode 6 ended at step 500 (terminated: False, truncated: True).
# Starting episode 7/1000...
#   Episode 7 ended at step 500 (terminated: False, truncated: True).
# Starting episode 8/1000...
#   Episode 8 ended at step 500 (terminated: False, truncated: True).
# Starting episode 9/1000...
#   Episode 9 ended at step 500 (terminated: False, truncated: True).
# Starting episode 10/1000...
#   Episode 10 ended at step 500 (terminated: False, truncated: True).
# Starting episode 11/1000...
#   Episode 11 ended at step 500 (terminated: False, truncated: True).
# Starting episode 12/1000...
#   Episode 12 ended at step 500 (terminated: False, truncated: True).
# Starting episode 13/1000...
#   Episode 13 ended at step 500 (terminated: False, truncated: True).
# Starting episode 14/1000...
#   Episode 14 ended at step 500 (terminated: False, truncated: True).
# Starting episode 15/1000...
#   Episode 15 ended at step 500 (terminated: False, truncated: True).
# Starting episode 16/1000...
#   Episode 16 ended at step 500 (terminated: False, truncated: True).
# Starting episode 17/1000...
#   Episode 17 ended at step 500 (terminated: False, truncated: True).
# Starting episode 18/1000...
#   Episode 18 ended at step 500 (terminated: False, truncated: True).
# Starting episode 19/1000...
#   Episode 19 ended at step 500 (terminated: False, truncated: True).
# Starting episode 20/1000...
#   Episode 20 ended at step 500 (terminated: False, truncated: True).
# Starting episode 21/1000...
#   Episode 21 ended at step 500 (terminated: False, truncated: True).
# Starting episode 22/1000...
#   Episode 22 ended at step 500 (terminated: False, truncated: True).
# Starting episode 23/1000...
#   Episode 23 ended at step 500 (terminated: False, truncated: True).
# Starting episode 24/1000...
#   Episode 24 ended at step 500 (terminated: False, truncated: True).
# Starting episode 25/1000...
#   Episode 25 ended at step 500 (terminated: False, truncated: True).
# Starting episode 26/1000...
#   Episode 26 ended at step 500 (terminated: False, truncated: True).
# Starting episode 27/1000...
#   Episode 27 ended at step 500 (terminated: False, truncated: True).
# Starting episode 28/1000...
#   Episode 28 ended at step 500 (terminated: False, truncated: True).
# Starting episode 29/1000...
#   Episode 29 ended at step 500 (terminated: False, truncated: True).
# Starting episode 30/1000...
#   Episode 30 ended at step 500 (terminated: False, truncated: True).
# Starting episode 31/1000...
#   Episode 31 ended at step 500 (terminated: False, truncated: True).
# Starting episode 32/1000...
#   Episode 32 ended at step 500 (terminated: False, truncated: True).
# Starting episode 33/1000...
#   Episode 33 ended at step 500 (terminated: False, truncated: True).
# Starting episode 34/1000...
#   Episode 34 ended at step 500 (terminated: False, truncated: True).
# Starting episode 35/1000...
#   Episode 35 ended at step 500 (terminated: False, truncated: True).
# Starting episode 36/1000...
#   Episode 36 ended at step 500 (terminated: False, truncated: True).
# Starting episode 37/1000...
#   Episode 37 ended at step 500 (terminated: False, truncated: True).
# Starting episode 38/1000...
#   Episode 38 ended at step 500 (terminated: False, truncated: True).
# Starting episode 39/1000...
#   Episode 39 ended at step 500 (terminated: False, truncated: True).
# Starting episode 40/1000...
#   Episode 40 ended at step 500 (terminated: False, truncated: True).
# Starting episode 41/1000...
#   Episode 41 ended at step 500 (terminated: False, truncated: True).
# Starting episode 42/1000...
#   Episode 42 ended at step 500 (terminated: False, truncated: True).
# Starting episode 43/1000...
#   Episode 43 ended at step 500 (terminated: False, truncated: True).
# Starting episode 44/1000...
#   Episode 44 ended at step 500 (terminated: False, truncated: True).
# Starting episode 45/1000...
#   Episode 45 ended at step 500 (terminated: False, truncated: True).
# Starting episode 46/1000...
#   Episode 46 ended at step 500 (terminated: False, truncated: True).
# Starting episode 47/1000...
#   Episode 47 ended at step 500 (terminated: False, truncated: True).
# Starting episode 48/1000...
#   Episode 48 ended at step 500 (terminated: False, truncated: True).
# Starting episode 49/1000...
#   Episode 49 ended at step 500 (terminated: False, truncated: True).
# Starting episode 50/1000...
#   Episode 50 ended at step 500 (terminated: False, truncated: True).
# Starting episode 51/1000...
#   Episode 51 ended at step 500 (terminated: False, truncated: True).
# Starting episode 52/1000...
#   Episode 52 ended at step 500 (terminated: False, truncated: True).
# Starting episode 53/1000...
#   Episode 53 ended at step 500 (terminated: False, truncated: True).
# Starting episode 54/1000...
#   Episode 54 ended at step 500 (terminated: False, truncated: True).
# Starting episode 55/1000...
#   Episode 55 ended at step 500 (terminated: False, truncated: True).
# Starting episode 56/1000...
#   Episode 56 ended at step 500 (terminated: False, truncated: True).
# Starting episode 57/1000...
#   Episode 57 ended at step 500 (terminated: False, truncated: True).
# Starting episode 58/1000...
#   Episode 58 ended at step 500 (terminated: False, truncated: True).
# Starting episode 59/1000...
#   Episode 59 ended at step 500 (terminated: False, truncated: True).
# Starting episode 60/1000...
#   Episode 60 ended at step 500 (terminated: False, truncated: True).
# Starting episode 61/1000...
#   Episode 61 ended at step 500 (terminated: False, truncated: True).
# Starting episode 62/1000...
#   Episode 62 ended at step 500 (terminated: False, truncated: True).
# Starting episode 63/1000...
#   Episode 63 ended at step 500 (terminated: False, truncated: True).
# Starting episode 64/1000...
#   Episode 64 ended at step 500 (terminated: False, truncated: True).
# Starting episode 65/1000...
#   Episode 65 ended at step 500 (terminated: False, truncated: True).
# Starting episode 66/1000...
#   Episode 66 ended at step 500 (terminated: False, truncated: True).
# Starting episode 67/1000...
#   Episode 67 ended at step 500 (terminated: False, truncated: True).
# Starting episode 68/1000...
#   Episode 68 ended at step 500 (terminated: False, truncated: True).
# Starting episode 69/1000...
#   Episode 69 ended at step 500 (terminated: False, truncated: True).
# Starting episode 70/1000...
#   Episode 70 ended at step 500 (terminated: False, truncated: True).
# Starting episode 71/1000...
#   Episode 71 ended at step 500 (terminated: False, truncated: True).
# Starting episode 72/1000...
#   Episode 72 ended at step 500 (terminated: False, truncated: True).
# Starting episode 73/1000...
#   Episode 73 ended at step 500 (terminated: False, truncated: True).
# Starting episode 74/1000...
#   Episode 74 ended at step 500 (terminated: False, truncated: True).
# Starting episode 75/1000...
#   Episode 75 ended at step 500 (terminated: False, truncated: True).
# Starting episode 76/1000...
#   Episode 76 ended at step 500 (terminated: False, truncated: True).
# Starting episode 77/1000...
#   Episode 77 ended at step 500 (terminated: False, truncated: True).
# Starting episode 78/1000...
#   Episode 78 ended at step 500 (terminated: False, truncated: True).
# Starting episode 79/1000...
#   Episode 79 ended at step 500 (terminated: False, truncated: True).
# Starting episode 80/1000...
#   Episode 80 ended at step 500 (terminated: False, truncated: True).
# Starting episode 81/1000...
#   Episode 81 ended at step 500 (terminated: False, truncated: True).
# Starting episode 82/1000...
#   Episode 82 ended at step 500 (terminated: False, truncated: True).
# Starting episode 83/1000...
#   Episode 83 ended at step 500 (terminated: False, truncated: True).
# Starting episode 84/1000...
#   Episode 84 ended at step 500 (terminated: False, truncated: True).
# Starting episode 85/1000...
#   Episode 85 ended at step 500 (terminated: False, truncated: True).
# Starting episode 86/1000...
#   Episode 86 ended at step 500 (terminated: False, truncated: True).
# Starting episode 87/1000...
#   Episode 87 ended at step 500 (terminated: False, truncated: True).
# Starting episode 88/1000...
#   Episode 88 ended at step 500 (terminated: False, truncated: True).
# Starting episode 89/1000...
#   Episode 89 ended at step 500 (terminated: False, truncated: True).
# Starting episode 90/1000...
#   Episode 90 ended at step 500 (terminated: False, truncated: True).
# Starting episode 91/1000...
#   Episode 91 ended at step 500 (terminated: False, truncated: True).
# Starting episode 92/1000...
#   Episode 92 ended at step 500 (terminated: False, truncated: True).
# Starting episode 93/1000...
#   Episode 93 ended at step 500 (terminated: False, truncated: True).
# Starting episode 94/1000...
#   Episode 94 ended at step 500 (terminated: False, truncated: True).
# Starting episode 95/1000...
#   Episode 95 ended at step 500 (terminated: False, truncated: True).
# Starting episode 96/1000...
#   Episode 96 ended at step 500 (terminated: False, truncated: True).
# Starting episode 97/1000...
#   Episode 97 ended at step 500 (terminated: False, truncated: True).
# Starting episode 98/1000...
#   Episode 98 ended at step 500 (terminated: False, truncated: True).
# Starting episode 99/1000...
#   Episode 99 ended at step 500 (terminated: False, truncated: True).
# Starting episode 100/1000...
#   Episode 100 ended at step 500 (terminated: False, truncated: True).
# Starting episode 101/1000...
#   Episode 101 ended at step 500 (terminated: False, truncated: True).
# Starting episode 102/1000...
#   Episode 102 ended at step 500 (terminated: False, truncated: True).
# Starting episode 103/1000...
#   Episode 103 ended at step 500 (terminated: False, truncated: True).
# Starting episode 104/1000...
#   Episode 104 ended at step 500 (terminated: False, truncated: True).
# Starting episode 105/1000...
#   Episode 105 ended at step 500 (terminated: False, truncated: True).
# Starting episode 106/1000...
#   Episode 106 ended at step 500 (terminated: False, truncated: True).
# Starting episode 107/1000...
#   Episode 107 ended at step 500 (terminated: False, truncated: True).
# Starting episode 108/1000...
#   Episode 108 ended at step 500 (terminated: False, truncated: True).
# Starting episode 109/1000...
#   Episode 109 ended at step 500 (terminated: False, truncated: True).
# Starting episode 110/1000...
#   Episode 110 ended at step 500 (terminated: False, truncated: True).
# Starting episode 111/1000...
#   Episode 111 ended at step 500 (terminated: False, truncated: True).
# Starting episode 112/1000...
#   Episode 112 ended at step 500 (terminated: False, truncated: True).
# Starting episode 113/1000...
#   Episode 113 ended at step 500 (terminated: False, truncated: True).
# Starting episode 114/1000...
#   Episode 114 ended at step 500 (terminated: False, truncated: True).
# Starting episode 115/1000...
#   Episode 115 ended at step 500 (terminated: False, truncated: True).
# Starting episode 116/1000...
#   Episode 116 ended at step 500 (terminated: False, truncated: True).
# Starting episode 117/1000...
#   Episode 117 ended at step 500 (terminated: False, truncated: True).
# Starting episode 118/1000...
#   Episode 118 ended at step 500 (terminated: False, truncated: True).
# Starting episode 119/1000...
#   Episode 119 ended at step 500 (terminated: False, truncated: True).
# Starting episode 120/1000...
#   Episode 120 ended at step 500 (terminated: False, truncated: True).
# Starting episode 121/1000...
#   Episode 121 ended at step 500 (terminated: False, truncated: True).
# Starting episode 122/1000...
#   Episode 122 ended at step 500 (terminated: False, truncated: True).
# Starting episode 123/1000...
#   Episode 123 ended at step 500 (terminated: False, truncated: True).
# Starting episode 124/1000...
#   Episode 124 ended at step 500 (terminated: False, truncated: True).
# Starting episode 125/1000...
#   Episode 125 ended at step 500 (terminated: False, truncated: True).
# Starting episode 126/1000...
#   Episode 126 ended at step 500 (terminated: False, truncated: True).
# Starting episode 127/1000...
#   Episode 127 ended at step 500 (terminated: False, truncated: True).
# Starting episode 128/1000...
#   Episode 128 ended at step 500 (terminated: False, truncated: True).
# Starting episode 129/1000...
#   Episode 129 ended at step 500 (terminated: False, truncated: True).
# Starting episode 130/1000...
#   Episode 130 ended at step 500 (terminated: False, truncated: True).
# Starting episode 131/1000...
#   Episode 131 ended at step 500 (terminated: False, truncated: True).
# Starting episode 132/1000...
#   Episode 132 ended at step 500 (terminated: False, truncated: True).
# Starting episode 133/1000...
#   Episode 133 ended at step 500 (terminated: False, truncated: True).
# Starting episode 134/1000...
#   Episode 134 ended at step 500 (terminated: False, truncated: True).
# Starting episode 135/1000...
#   Episode 135 ended at step 500 (terminated: False, truncated: True).
# Starting episode 136/1000...
#   Episode 136 ended at step 500 (terminated: False, truncated: True).
# Starting episode 137/1000...
#   Episode 137 ended at step 500 (terminated: False, truncated: True).
# Starting episode 138/1000...
#   Episode 138 ended at step 500 (terminated: False, truncated: True).
# Starting episode 139/1000...
#   Episode 139 ended at step 500 (terminated: False, truncated: True).
# Starting episode 140/1000...
#   Episode 140 ended at step 500 (terminated: False, truncated: True).
# Starting episode 141/1000...
#   Episode 141 ended at step 500 (terminated: False, truncated: True).
# Starting episode 142/1000...
#   Episode 142 ended at step 500 (terminated: False, truncated: True).
# Starting episode 143/1000...
#   Episode 143 ended at step 500 (terminated: False, truncated: True).
# Starting episode 144/1000...
#   Episode 144 ended at step 500 (terminated: False, truncated: True).
# Starting episode 145/1000...
#   Episode 145 ended at step 500 (terminated: False, truncated: True).
# Starting episode 146/1000...
#   Episode 146 ended at step 500 (terminated: False, truncated: True).
# Starting episode 147/1000...
#   Episode 147 ended at step 500 (terminated: False, truncated: True).
# Starting episode 148/1000...
#   Episode 148 ended at step 500 (terminated: False, truncated: True).
# Starting episode 149/1000...
#   Episode 149 ended at step 500 (terminated: False, truncated: True).
# Starting episode 150/1000...
#   Episode 150 ended at step 500 (terminated: False, truncated: True).
# Starting episode 151/1000...
#   Episode 151 ended at step 500 (terminated: False, truncated: True).
# Starting episode 152/1000...
#   Episode 152 ended at step 500 (terminated: False, truncated: True).
# Starting episode 153/1000...
#   Episode 153 ended at step 500 (terminated: False, truncated: True).
# Starting episode 154/1000...
#   Episode 154 ended at step 500 (terminated: False, truncated: True).
# Starting episode 155/1000...
#   Episode 155 ended at step 500 (terminated: False, truncated: True).
# Starting episode 156/1000...
#   Episode 156 ended at step 500 (terminated: False, truncated: True).
# Starting episode 157/1000...
#   Episode 157 ended at step 500 (terminated: False, truncated: True).
# Starting episode 158/1000...
#   Episode 158 ended at step 500 (terminated: False, truncated: True).
# Starting episode 159/1000...
#   Episode 159 ended at step 500 (terminated: False, truncated: True).
# Starting episode 160/1000...
#   Episode 160 ended at step 500 (terminated: False, truncated: True).
# Starting episode 161/1000...
#   Episode 161 ended at step 500 (terminated: False, truncated: True).
# Starting episode 162/1000...
#   Episode 162 ended at step 500 (terminated: False, truncated: True).
# Starting episode 163/1000...
#   Episode 163 ended at step 500 (terminated: False, truncated: True).
# Starting episode 164/1000...
#   Episode 164 ended at step 500 (terminated: False, truncated: True).
# Starting episode 165/1000...
#   Episode 165 ended at step 500 (terminated: False, truncated: True).
# Starting episode 166/1000...
#   Episode 166 ended at step 500 (terminated: False, truncated: True).
# Starting episode 167/1000...
#   Episode 167 ended at step 500 (terminated: False, truncated: True).
# Starting episode 168/1000...
#   Episode 168 ended at step 500 (terminated: False, truncated: True).
# Starting episode 169/1000...
#   Episode 169 ended at step 500 (terminated: False, truncated: True).
# Starting episode 170/1000...
#   Episode 170 ended at step 500 (terminated: False, truncated: True).
# Starting episode 171/1000...
#   Episode 171 ended at step 500 (terminated: False, truncated: True).
# Starting episode 172/1000...
#   Episode 172 ended at step 500 (terminated: False, truncated: True).
# Starting episode 173/1000...
#   Episode 173 ended at step 500 (terminated: False, truncated: True).
# Starting episode 174/1000...
#   Episode 174 ended at step 500 (terminated: False, truncated: True).
# Starting episode 175/1000...
#   Episode 175 ended at step 500 (terminated: False, truncated: True).
# Starting episode 176/1000...
#   Episode 176 ended at step 500 (terminated: False, truncated: True).
# Starting episode 177/1000...
#   Episode 177 ended at step 500 (terminated: False, truncated: True).
# Starting episode 178/1000...
#   Episode 178 ended at step 500 (terminated: False, truncated: True).
# Starting episode 179/1000...
#   Episode 179 ended at step 500 (terminated: False, truncated: True).
# Starting episode 180/1000...
#   Episode 180 ended at step 500 (terminated: False, truncated: True).
# Starting episode 181/1000...
#   Episode 181 ended at step 500 (terminated: False, truncated: True).
# Starting episode 182/1000...
#   Episode 182 ended at step 500 (terminated: False, truncated: True).
# Starting episode 183/1000...
#   Episode 183 ended at step 500 (terminated: False, truncated: True).
# Starting episode 184/1000...
#   Episode 184 ended at step 500 (terminated: False, truncated: True).
# Starting episode 185/1000...
#   Episode 185 ended at step 500 (terminated: False, truncated: True).
# Starting episode 186/1000...
#   Episode 186 ended at step 500 (terminated: False, truncated: True).
# Starting episode 187/1000...
#   Episode 187 ended at step 500 (terminated: False, truncated: True).
# Starting episode 188/1000...
#   Episode 188 ended at step 500 (terminated: False, truncated: True).
# Starting episode 189/1000...
#   Episode 189 ended at step 500 (terminated: False, truncated: True).
# Starting episode 190/1000...
#   Episode 190 ended at step 500 (terminated: False, truncated: True).
# Starting episode 191/1000...
#   Episode 191 ended at step 500 (terminated: False, truncated: True).
# Starting episode 192/1000...
#   Episode 192 ended at step 500 (terminated: False, truncated: True).
# Starting episode 193/1000...
#   Episode 193 ended at step 500 (terminated: False, truncated: True).
# Starting episode 194/1000...
#   Episode 194 ended at step 500 (terminated: False, truncated: True).
# Starting episode 195/1000...
#   Episode 195 ended at step 500 (terminated: False, truncated: True).
# Starting episode 196/1000...
#   Episode 196 ended at step 500 (terminated: False, truncated: True).
# Starting episode 197/1000...
#   Episode 197 ended at step 500 (terminated: False, truncated: True).
# Starting episode 198/1000...
#   Episode 198 ended at step 500 (terminated: False, truncated: True).
# Starting episode 199/1000...
#   Episode 199 ended at step 500 (terminated: False, truncated: True).
# Starting episode 200/1000...
#   Episode 200 ended at step 500 (terminated: False, truncated: True).
# Starting episode 201/1000...
#   Episode 201 ended at step 500 (terminated: False, truncated: True).
# Starting episode 202/1000...
#   Episode 202 ended at step 500 (terminated: False, truncated: True).
# Starting episode 203/1000...
#   Episode 203 ended at step 500 (terminated: False, truncated: True).
# Starting episode 204/1000...
#   Episode 204 ended at step 500 (terminated: False, truncated: True).
# Starting episode 205/1000...
#   Episode 205 ended at step 500 (terminated: False, truncated: True).
# Starting episode 206/1000...
#   Episode 206 ended at step 500 (terminated: False, truncated: True).
# Starting episode 207/1000...
#   Episode 207 ended at step 500 (terminated: False, truncated: True).
# Starting episode 208/1000...
#   Episode 208 ended at step 500 (terminated: False, truncated: True).
# Starting episode 209/1000...
#   Episode 209 ended at step 500 (terminated: False, truncated: True).
# Starting episode 210/1000...
#   Episode 210 ended at step 500 (terminated: False, truncated: True).
# Starting episode 211/1000...
#   Episode 211 ended at step 500 (terminated: False, truncated: True).
# Starting episode 212/1000...
#   Episode 212 ended at step 500 (terminated: False, truncated: True).
# Starting episode 213/1000...
#   Episode 213 ended at step 500 (terminated: False, truncated: True).
# Starting episode 214/1000...
#   Episode 214 ended at step 500 (terminated: False, truncated: True).
# Starting episode 215/1000...
#   Episode 215 ended at step 500 (terminated: False, truncated: True).
# Starting episode 216/1000...
#   Episode 216 ended at step 500 (terminated: False, truncated: True).
# Starting episode 217/1000...
#   Episode 217 ended at step 500 (terminated: False, truncated: True).
# Starting episode 218/1000...
#   Episode 218 ended at step 500 (terminated: False, truncated: True).
# Starting episode 219/1000...
#   Episode 219 ended at step 500 (terminated: False, truncated: True).
# Starting episode 220/1000...
#   Episode 220 ended at step 500 (terminated: False, truncated: True).
# Starting episode 221/1000...
#   Episode 221 ended at step 500 (terminated: False, truncated: True).
# Starting episode 222/1000...
#   Episode 222 ended at step 500 (terminated: False, truncated: True).
# Starting episode 223/1000...
#   Episode 223 ended at step 500 (terminated: False, truncated: True).
# Starting episode 224/1000...
#   Episode 224 ended at step 500 (terminated: False, truncated: True).
# Starting episode 225/1000...
#   Episode 225 ended at step 500 (terminated: False, truncated: True).
# Starting episode 226/1000...
#   Episode 226 ended at step 500 (terminated: False, truncated: True).
# Starting episode 227/1000...
#   Episode 227 ended at step 500 (terminated: False, truncated: True).
# Starting episode 228/1000...
#   Episode 228 ended at step 500 (terminated: False, truncated: True).
# Starting episode 229/1000...
#   Episode 229 ended at step 500 (terminated: False, truncated: True).
# Starting episode 230/1000...
#   Episode 230 ended at step 500 (terminated: False, truncated: True).
# Starting episode 231/1000...
#   Episode 231 ended at step 500 (terminated: False, truncated: True).
# Starting episode 232/1000...
#   Episode 232 ended at step 500 (terminated: False, truncated: True).
# Starting episode 233/1000...
#   Episode 233 ended at step 500 (terminated: False, truncated: True).
# Starting episode 234/1000...
#   Episode 234 ended at step 500 (terminated: False, truncated: True).
# Starting episode 235/1000...
#   Episode 235 ended at step 500 (terminated: False, truncated: True).
# Starting episode 236/1000...
#   Episode 236 ended at step 500 (terminated: False, truncated: True).
# Starting episode 237/1000...
#   Episode 237 ended at step 500 (terminated: False, truncated: True).
# Starting episode 238/1000...
#   Episode 238 ended at step 500 (terminated: False, truncated: True).
# Starting episode 239/1000...
#   Episode 239 ended at step 500 (terminated: False, truncated: True).
# Starting episode 240/1000...
#   Episode 240 ended at step 500 (terminated: False, truncated: True).
# Starting episode 241/1000...
#   Episode 241 ended at step 500 (terminated: False, truncated: True).
# Starting episode 242/1000...
#   Episode 242 ended at step 500 (terminated: False, truncated: True).
# Starting episode 243/1000...
#   Episode 243 ended at step 500 (terminated: False, truncated: True).
# Starting episode 244/1000...
#   Episode 244 ended at step 500 (terminated: False, truncated: True).
# Starting episode 245/1000...
#   Episode 245 ended at step 500 (terminated: False, truncated: True).
# Starting episode 246/1000...
#   Episode 246 ended at step 500 (terminated: False, truncated: True).
# Starting episode 247/1000...
#   Episode 247 ended at step 500 (terminated: False, truncated: True).
# Starting episode 248/1000...
#   Episode 248 ended at step 500 (terminated: False, truncated: True).
# Starting episode 249/1000...
#   Episode 249 ended at step 500 (terminated: False, truncated: True).
# Starting episode 250/1000...
#   Episode 250 ended at step 500 (terminated: False, truncated: True).
# Starting episode 251/1000...
#   Episode 251 ended at step 500 (terminated: False, truncated: True).
# Starting episode 252/1000...
#   Episode 252 ended at step 500 (terminated: False, truncated: True).
# Starting episode 253/1000...
#   Episode 253 ended at step 500 (terminated: False, truncated: True).
# Starting episode 254/1000...
#   Episode 254 ended at step 500 (terminated: False, truncated: True).
# Starting episode 255/1000...
#   Episode 255 ended at step 500 (terminated: False, truncated: True).
# Starting episode 256/1000...
#   Episode 256 ended at step 500 (terminated: False, truncated: True).
# Starting episode 257/1000...
#   Episode 257 ended at step 500 (terminated: False, truncated: True).
# Starting episode 258/1000...
#   Episode 258 ended at step 500 (terminated: False, truncated: True).
# Starting episode 259/1000...
#   Episode 259 ended at step 500 (terminated: False, truncated: True).
# Starting episode 260/1000...
#   Episode 260 ended at step 500 (terminated: False, truncated: True).
# Starting episode 261/1000...
#   Episode 261 ended at step 500 (terminated: False, truncated: True).
# Starting episode 262/1000...
#   Episode 262 ended at step 500 (terminated: False, truncated: True).
# Starting episode 263/1000...
#   Episode 263 ended at step 500 (terminated: False, truncated: True).
# Starting episode 264/1000...
#   Episode 264 ended at step 500 (terminated: False, truncated: True).
# Starting episode 265/1000...
#   Episode 265 ended at step 500 (terminated: False, truncated: True).
# Starting episode 266/1000...
#   Episode 266 ended at step 500 (terminated: False, truncated: True).
# Starting episode 267/1000...
#   Episode 267 ended at step 500 (terminated: False, truncated: True).
# Starting episode 268/1000...
#   Episode 268 ended at step 500 (terminated: False, truncated: True).
# Starting episode 269/1000...
#   Episode 269 ended at step 500 (terminated: False, truncated: True).
# Starting episode 270/1000...
#   Episode 270 ended at step 500 (terminated: False, truncated: True).
# Starting episode 271/1000...
#   Episode 271 ended at step 500 (terminated: False, truncated: True).
# Starting episode 272/1000...
#   Episode 272 ended at step 500 (terminated: False, truncated: True).
# Starting episode 273/1000...
#   Episode 273 ended at step 500 (terminated: False, truncated: True).
# Starting episode 274/1000...
#   Episode 274 ended at step 500 (terminated: False, truncated: True).
# Starting episode 275/1000...
#   Episode 275 ended at step 500 (terminated: False, truncated: True).
# Starting episode 276/1000...
#   Episode 276 ended at step 500 (terminated: False, truncated: True).
# Starting episode 277/1000...
#   Episode 277 ended at step 500 (terminated: False, truncated: True).
# Starting episode 278/1000...
#   Episode 278 ended at step 500 (terminated: False, truncated: True).
# Starting episode 279/1000...
#   Episode 279 ended at step 500 (terminated: False, truncated: True).
# Starting episode 280/1000...
#   Episode 280 ended at step 500 (terminated: False, truncated: True).
# Starting episode 281/1000...
#   Episode 281 ended at step 500 (terminated: False, truncated: True).
# Starting episode 282/1000...
#   Episode 282 ended at step 500 (terminated: False, truncated: True).
# Starting episode 283/1000...
#   Episode 283 ended at step 500 (terminated: False, truncated: True).
# Starting episode 284/1000...
#   Episode 284 ended at step 500 (terminated: False, truncated: True).
# Starting episode 285/1000...
#   Episode 285 ended at step 500 (terminated: False, truncated: True).
# Starting episode 286/1000...
#   Episode 286 ended at step 500 (terminated: False, truncated: True).
# Starting episode 287/1000...
#   Episode 287 ended at step 500 (terminated: False, truncated: True).
# Starting episode 288/1000...
#   Episode 288 ended at step 500 (terminated: False, truncated: True).
# Starting episode 289/1000...
#   Episode 289 ended at step 500 (terminated: False, truncated: True).
# Starting episode 290/1000...
#   Episode 290 ended at step 500 (terminated: False, truncated: True).
# Starting episode 291/1000...
#   Episode 291 ended at step 500 (terminated: False, truncated: True).
# Starting episode 292/1000...
#   Episode 292 ended at step 500 (terminated: False, truncated: True).
# Starting episode 293/1000...
#   Episode 293 ended at step 500 (terminated: False, truncated: True).
# Starting episode 294/1000...
#   Episode 294 ended at step 500 (terminated: False, truncated: True).
# Starting episode 295/1000...
#   Episode 295 ended at step 500 (terminated: False, truncated: True).
# Starting episode 296/1000...
#   Episode 296 ended at step 500 (terminated: False, truncated: True).
# Starting episode 297/1000...
#   Episode 297 ended at step 500 (terminated: False, truncated: True).
# Starting episode 298/1000...
#   Episode 298 ended at step 500 (terminated: False, truncated: True).
# Starting episode 299/1000...
#   Episode 299 ended at step 500 (terminated: False, truncated: True).
# Starting episode 300/1000...
#   Episode 300 ended at step 500 (terminated: False, truncated: True).
# Starting episode 301/1000...
#   Episode 301 ended at step 500 (terminated: False, truncated: True).
# Starting episode 302/1000...
#   Episode 302 ended at step 500 (terminated: False, truncated: True).
# Starting episode 303/1000...
#   Episode 303 ended at step 500 (terminated: False, truncated: True).
# Starting episode 304/1000...
#   Episode 304 ended at step 500 (terminated: False, truncated: True).
# Starting episode 305/1000...
#   Episode 305 ended at step 500 (terminated: False, truncated: True).
# Starting episode 306/1000...
#   Episode 306 ended at step 500 (terminated: False, truncated: True).
# Starting episode 307/1000...
#   Episode 307 ended at step 500 (terminated: False, truncated: True).
# Starting episode 308/1000...
#   Episode 308 ended at step 500 (terminated: False, truncated: True).
# Starting episode 309/1000...
#   Episode 309 ended at step 500 (terminated: False, truncated: True).
# Starting episode 310/1000...
#   Episode 310 ended at step 500 (terminated: False, truncated: True).
# Starting episode 311/1000...
#   Episode 311 ended at step 500 (terminated: False, truncated: True).
# Starting episode 312/1000...
#   Episode 312 ended at step 500 (terminated: False, truncated: True).
# Starting episode 313/1000...
#   Episode 313 ended at step 500 (terminated: False, truncated: True).
# Starting episode 314/1000...
#   Episode 314 ended at step 500 (terminated: False, truncated: True).
# Starting episode 315/1000...
#   Episode 315 ended at step 500 (terminated: False, truncated: True).
# Starting episode 316/1000...
#   Episode 316 ended at step 500 (terminated: False, truncated: True).
# Starting episode 317/1000...
#   Episode 317 ended at step 500 (terminated: False, truncated: True).
# Starting episode 318/1000...
#   Episode 318 ended at step 500 (terminated: False, truncated: True).
# Starting episode 319/1000...
#   Episode 319 ended at step 500 (terminated: False, truncated: True).
# Starting episode 320/1000...
#   Episode 320 ended at step 500 (terminated: False, truncated: True).
# Starting episode 321/1000...
#   Episode 321 ended at step 500 (terminated: False, truncated: True).
# Starting episode 322/1000...
#   Episode 322 ended at step 500 (terminated: False, truncated: True).
# Starting episode 323/1000...
#   Episode 323 ended at step 500 (terminated: False, truncated: True).
# Starting episode 324/1000...
#   Episode 324 ended at step 500 (terminated: False, truncated: True).
# Starting episode 325/1000...
#   Episode 325 ended at step 500 (terminated: False, truncated: True).
# Starting episode 326/1000...
#   Episode 326 ended at step 500 (terminated: False, truncated: True).
# Starting episode 327/1000...
#   Episode 327 ended at step 500 (terminated: False, truncated: True).
# Starting episode 328/1000...
#   Episode 328 ended at step 500 (terminated: False, truncated: True).
# Starting episode 329/1000...
#   Episode 329 ended at step 500 (terminated: False, truncated: True).
# Starting episode 330/1000...
#   Episode 330 ended at step 500 (terminated: False, truncated: True).
# Starting episode 331/1000...
#   Episode 331 ended at step 500 (terminated: False, truncated: True).
# Starting episode 332/1000...
#   Episode 332 ended at step 500 (terminated: False, truncated: True).
# Starting episode 333/1000...
#   Episode 333 ended at step 500 (terminated: False, truncated: True).
# Starting episode 334/1000...
#   Episode 334 ended at step 500 (terminated: False, truncated: True).
# Starting episode 335/1000...
#   Episode 335 ended at step 500 (terminated: False, truncated: True).
# Starting episode 336/1000...
#   Episode 336 ended at step 500 (terminated: False, truncated: True).
# Starting episode 337/1000...
#   Episode 337 ended at step 500 (terminated: False, truncated: True).
# Starting episode 338/1000...
#   Episode 338 ended at step 500 (terminated: False, truncated: True).
# Starting episode 339/1000...
#   Episode 339 ended at step 500 (terminated: False, truncated: True).
# Starting episode 340/1000...
#   Episode 340 ended at step 500 (terminated: False, truncated: True).
# Starting episode 341/1000...
#   Episode 341 ended at step 500 (terminated: False, truncated: True).
# Starting episode 342/1000...
#   Episode 342 ended at step 500 (terminated: False, truncated: True).
# Starting episode 343/1000...
#   Episode 343 ended at step 500 (terminated: False, truncated: True).
# Starting episode 344/1000...
#   Episode 344 ended at step 500 (terminated: False, truncated: True).
# Starting episode 345/1000...
#   Episode 345 ended at step 500 (terminated: False, truncated: True).
# Starting episode 346/1000...
#   Episode 346 ended at step 500 (terminated: False, truncated: True).
# Starting episode 347/1000...
#   Episode 347 ended at step 500 (terminated: False, truncated: True).
# Starting episode 348/1000...
#   Episode 348 ended at step 500 (terminated: False, truncated: True).
# Starting episode 349/1000...
#   Episode 349 ended at step 500 (terminated: False, truncated: True).
# Starting episode 350/1000...
#   Episode 350 ended at step 500 (terminated: False, truncated: True).
# Starting episode 351/1000...
#   Episode 351 ended at step 500 (terminated: False, truncated: True).
# Starting episode 352/1000...
#   Episode 352 ended at step 500 (terminated: False, truncated: True).
# Starting episode 353/1000...
#   Episode 353 ended at step 500 (terminated: False, truncated: True).
# Starting episode 354/1000...
#   Episode 354 ended at step 500 (terminated: False, truncated: True).
# Starting episode 355/1000...
#   Episode 355 ended at step 500 (terminated: False, truncated: True).
# Starting episode 356/1000...
#   Episode 356 ended at step 500 (terminated: False, truncated: True).
# Starting episode 357/1000...
#   Episode 357 ended at step 500 (terminated: False, truncated: True).
# Starting episode 358/1000...
#   Episode 358 ended at step 500 (terminated: False, truncated: True).
# Starting episode 359/1000...
#   Episode 359 ended at step 500 (terminated: False, truncated: True).
# Starting episode 360/1000...
#   Episode 360 ended at step 500 (terminated: False, truncated: True).
# Starting episode 361/1000...
#   Episode 361 ended at step 500 (terminated: False, truncated: True).
# Starting episode 362/1000...
#   Episode 362 ended at step 500 (terminated: False, truncated: True).
# Starting episode 363/1000...
#   Episode 363 ended at step 500 (terminated: False, truncated: True).
# Starting episode 364/1000...
#   Episode 364 ended at step 500 (terminated: False, truncated: True).
# Starting episode 365/1000...
#   Episode 365 ended at step 500 (terminated: False, truncated: True).
# Starting episode 366/1000...
#   Episode 366 ended at step 500 (terminated: False, truncated: True).
# Starting episode 367/1000...
#   Episode 367 ended at step 500 (terminated: False, truncated: True).
# Starting episode 368/1000...
#   Episode 368 ended at step 500 (terminated: False, truncated: True).
# Starting episode 369/1000...
#   Episode 369 ended at step 500 (terminated: False, truncated: True).
# Starting episode 370/1000...
#   Episode 370 ended at step 500 (terminated: False, truncated: True).
# Starting episode 371/1000...
#   Episode 371 ended at step 500 (terminated: False, truncated: True).
# Starting episode 372/1000...
#   Episode 372 ended at step 500 (terminated: False, truncated: True).
# Starting episode 373/1000...
#   Episode 373 ended at step 500 (terminated: False, truncated: True).
# Starting episode 374/1000...
#   Episode 374 ended at step 500 (terminated: False, truncated: True).
# Starting episode 375/1000...
#   Episode 375 ended at step 500 (terminated: False, truncated: True).
# Starting episode 376/1000...
#   Episode 376 ended at step 500 (terminated: False, truncated: True).
# Starting episode 377/1000...
#   Episode 377 ended at step 500 (terminated: False, truncated: True).
# Starting episode 378/1000...
#   Episode 378 ended at step 500 (terminated: False, truncated: True).
# Starting episode 379/1000...
#   Episode 379 ended at step 500 (terminated: False, truncated: True).
# Starting episode 380/1000...
#   Episode 380 ended at step 500 (terminated: False, truncated: True).
# Starting episode 381/1000...
#   Episode 381 ended at step 500 (terminated: False, truncated: True).
# Starting episode 382/1000...
#   Episode 382 ended at step 500 (terminated: False, truncated: True).
# Starting episode 383/1000...
#   Episode 383 ended at step 500 (terminated: False, truncated: True).
# Starting episode 384/1000...
#   Episode 384 ended at step 500 (terminated: False, truncated: True).
# Starting episode 385/1000...
#   Episode 385 ended at step 500 (terminated: False, truncated: True).
# Starting episode 386/1000...
#   Episode 386 ended at step 500 (terminated: False, truncated: True).
# Starting episode 387/1000...
#   Episode 387 ended at step 500 (terminated: False, truncated: True).
# Starting episode 388/1000...
#   Episode 388 ended at step 500 (terminated: False, truncated: True).
# Starting episode 389/1000...
#   Episode 389 ended at step 500 (terminated: False, truncated: True).
# Starting episode 390/1000...
#   Episode 390 ended at step 500 (terminated: False, truncated: True).
# Starting episode 391/1000...
#   Episode 391 ended at step 500 (terminated: False, truncated: True).
# Starting episode 392/1000...
#   Episode 392 ended at step 500 (terminated: False, truncated: True).
# Starting episode 393/1000...
#   Episode 393 ended at step 500 (terminated: False, truncated: True).
# Starting episode 394/1000...
#   Episode 394 ended at step 500 (terminated: False, truncated: True).
# Starting episode 395/1000...
#   Episode 395 ended at step 500 (terminated: False, truncated: True).
# Starting episode 396/1000...
#   Episode 396 ended at step 500 (terminated: False, truncated: True).
# Starting episode 397/1000...
#   Episode 397 ended at step 500 (terminated: False, truncated: True).
# Starting episode 398/1000...
#   Episode 398 ended at step 500 (terminated: False, truncated: True).
# Starting episode 399/1000...
#   Episode 399 ended at step 500 (terminated: False, truncated: True).
# Starting episode 400/1000...
#   Episode 400 ended at step 500 (terminated: False, truncated: True).
# Starting episode 401/1000...
#   Episode 401 ended at step 500 (terminated: False, truncated: True).
# Starting episode 402/1000...
#   Episode 402 ended at step 500 (terminated: False, truncated: True).
# Starting episode 403/1000...
#   Episode 403 ended at step 500 (terminated: False, truncated: True).
# Starting episode 404/1000...
#   Episode 404 ended at step 500 (terminated: False, truncated: True).
# Starting episode 405/1000...
#   Episode 405 ended at step 500 (terminated: False, truncated: True).
# Starting episode 406/1000...
#   Episode 406 ended at step 500 (terminated: False, truncated: True).
# Starting episode 407/1000...
#   Episode 407 ended at step 500 (terminated: False, truncated: True).
# Starting episode 408/1000...
#   Episode 408 ended at step 500 (terminated: False, truncated: True).
# Starting episode 409/1000...
#   Episode 409 ended at step 500 (terminated: False, truncated: True).
# Starting episode 410/1000...
#   Episode 410 ended at step 500 (terminated: False, truncated: True).
# Starting episode 411/1000...
#   Episode 411 ended at step 500 (terminated: False, truncated: True).
# Starting episode 412/1000...
#   Episode 412 ended at step 500 (terminated: False, truncated: True).
# Starting episode 413/1000...
#   Episode 413 ended at step 500 (terminated: False, truncated: True).
# Starting episode 414/1000...
#   Episode 414 ended at step 500 (terminated: False, truncated: True).
# Starting episode 415/1000...
#   Episode 415 ended at step 500 (terminated: False, truncated: True).
# Starting episode 416/1000...
#   Episode 416 ended at step 500 (terminated: False, truncated: True).
# Starting episode 417/1000...
#   Episode 417 ended at step 500 (terminated: False, truncated: True).
# Starting episode 418/1000...
#   Episode 418 ended at step 500 (terminated: False, truncated: True).
# Starting episode 419/1000...
#   Episode 419 ended at step 500 (terminated: False, truncated: True).
# Starting episode 420/1000...
#   Episode 420 ended at step 500 (terminated: False, truncated: True).
# Starting episode 421/1000...
#   Episode 421 ended at step 500 (terminated: False, truncated: True).
# Starting episode 422/1000...
#   Episode 422 ended at step 500 (terminated: False, truncated: True).
# Starting episode 423/1000...
#   Episode 423 ended at step 500 (terminated: False, truncated: True).
# Starting episode 424/1000...
#   Episode 424 ended at step 500 (terminated: False, truncated: True).
# Starting episode 425/1000...
#   Episode 425 ended at step 500 (terminated: False, truncated: True).
# Starting episode 426/1000...
#   Episode 426 ended at step 500 (terminated: False, truncated: True).
# Starting episode 427/1000...
#   Episode 427 ended at step 500 (terminated: False, truncated: True).
# Starting episode 428/1000...
#   Episode 428 ended at step 500 (terminated: False, truncated: True).
# Starting episode 429/1000...
#   Episode 429 ended at step 500 (terminated: False, truncated: True).
# Starting episode 430/1000...
#   Episode 430 ended at step 500 (terminated: False, truncated: True).
# Starting episode 431/1000...
#   Episode 431 ended at step 500 (terminated: False, truncated: True).
# Starting episode 432/1000...
#   Episode 432 ended at step 500 (terminated: False, truncated: True).
# Starting episode 433/1000...
#   Episode 433 ended at step 500 (terminated: False, truncated: True).
# Starting episode 434/1000...
#   Episode 434 ended at step 500 (terminated: False, truncated: True).
# Starting episode 435/1000...
#   Episode 435 ended at step 500 (terminated: False, truncated: True).
# Starting episode 436/1000...
#   Episode 436 ended at step 500 (terminated: False, truncated: True).
# Starting episode 437/1000...
#   Episode 437 ended at step 500 (terminated: False, truncated: True).
# Starting episode 438/1000...
#   Episode 438 ended at step 500 (terminated: False, truncated: True).
# Starting episode 439/1000...
#   Episode 439 ended at step 500 (terminated: False, truncated: True).
# Starting episode 440/1000...
#   Episode 440 ended at step 500 (terminated: False, truncated: True).
# Starting episode 441/1000...
#   Episode 441 ended at step 500 (terminated: False, truncated: True).
# Starting episode 442/1000...
#   Episode 442 ended at step 500 (terminated: False, truncated: True).
# Starting episode 443/1000...
#   Episode 443 ended at step 500 (terminated: False, truncated: True).
# Starting episode 444/1000...
#   Episode 444 ended at step 500 (terminated: False, truncated: True).
# Starting episode 445/1000...
#   Episode 445 ended at step 500 (terminated: False, truncated: True).
# Starting episode 446/1000...
#   Episode 446 ended at step 500 (terminated: False, truncated: True).
# Starting episode 447/1000...
#   Episode 447 ended at step 500 (terminated: False, truncated: True).
# Starting episode 448/1000...
#   Episode 448 ended at step 500 (terminated: False, truncated: True).
# Starting episode 449/1000...
#   Episode 449 ended at step 500 (terminated: False, truncated: True).
# Starting episode 450/1000...
#   Episode 450 ended at step 500 (terminated: False, truncated: True).
# Starting episode 451/1000...
#   Episode 451 ended at step 500 (terminated: False, truncated: True).
# Starting episode 452/1000...
#   Episode 452 ended at step 500 (terminated: False, truncated: True).
# Starting episode 453/1000...
#   Episode 453 ended at step 500 (terminated: False, truncated: True).
# Starting episode 454/1000...
#   Episode 454 ended at step 500 (terminated: False, truncated: True).
# Starting episode 455/1000...
#   Episode 455 ended at step 500 (terminated: False, truncated: True).
# Starting episode 456/1000...
#   Episode 456 ended at step 500 (terminated: False, truncated: True).
# Starting episode 457/1000...
#   Episode 457 ended at step 500 (terminated: False, truncated: True).
# Starting episode 458/1000...
#   Episode 458 ended at step 500 (terminated: False, truncated: True).
# Starting episode 459/1000...
#   Episode 459 ended at step 500 (terminated: False, truncated: True).
# Starting episode 460/1000...
#   Episode 460 ended at step 500 (terminated: False, truncated: True).
# Starting episode 461/1000...
#   Episode 461 ended at step 500 (terminated: False, truncated: True).
# Starting episode 462/1000...
#   Episode 462 ended at step 500 (terminated: False, truncated: True).
# Starting episode 463/1000...
#   Episode 463 ended at step 500 (terminated: False, truncated: True).
# Starting episode 464/1000...
#   Episode 464 ended at step 500 (terminated: False, truncated: True).
# Starting episode 465/1000...
#   Episode 465 ended at step 500 (terminated: False, truncated: True).
# Starting episode 466/1000...
#   Episode 466 ended at step 500 (terminated: False, truncated: True).
# Starting episode 467/1000...
#   Episode 467 ended at step 500 (terminated: False, truncated: True).
# Starting episode 468/1000...
#   Episode 468 ended at step 500 (terminated: False, truncated: True).
# Starting episode 469/1000...
#   Episode 469 ended at step 500 (terminated: False, truncated: True).
# Starting episode 470/1000...
#   Episode 470 ended at step 500 (terminated: False, truncated: True).
# Starting episode 471/1000...
#   Episode 471 ended at step 500 (terminated: False, truncated: True).
# Starting episode 472/1000...
#   Episode 472 ended at step 500 (terminated: False, truncated: True).
# Starting episode 473/1000...
#   Episode 473 ended at step 500 (terminated: False, truncated: True).
# Starting episode 474/1000...
#   Episode 474 ended at step 500 (terminated: False, truncated: True).
# Starting episode 475/1000...
#   Episode 475 ended at step 500 (terminated: False, truncated: True).
# Starting episode 476/1000...
#   Episode 476 ended at step 500 (terminated: False, truncated: True).
# Starting episode 477/1000...
#   Episode 477 ended at step 500 (terminated: False, truncated: True).
# Starting episode 478/1000...
#   Episode 478 ended at step 500 (terminated: False, truncated: True).
# Starting episode 479/1000...
#   Episode 479 ended at step 500 (terminated: False, truncated: True).
# Starting episode 480/1000...
#   Episode 480 ended at step 500 (terminated: False, truncated: True).
# Starting episode 481/1000...
#   Episode 481 ended at step 500 (terminated: False, truncated: True).
# Starting episode 482/1000...
#   Episode 482 ended at step 500 (terminated: False, truncated: True).
# Starting episode 483/1000...
#   Episode 483 ended at step 500 (terminated: False, truncated: True).
# Starting episode 484/1000...
#   Episode 484 ended at step 500 (terminated: False, truncated: True).
# Starting episode 485/1000...
#   Episode 485 ended at step 500 (terminated: False, truncated: True).
# Starting episode 486/1000...
#   Episode 486 ended at step 500 (terminated: False, truncated: True).
# Starting episode 487/1000...
#   Episode 487 ended at step 500 (terminated: False, truncated: True).
# ...
# Starting episode 840/1000...
#   Episode 840 ended at step 500 (terminated: False, truncated: True).
# Starting episode 841/1000...
#   Episode 841 ended at step 500 (terminated: False, truncated: True).
# Starting episode 842/1000...
#   Episode 842 ended at step 500 (terminated: False, truncated: True).
# Starting episode 843/1000...
#   Episode 843 ended at step 500 (terminated: False, truncated: True).
# Starting episode 844/1000...
#   Episode 844 ended at step 500 (terminated: False, truncated: True).
# Starting episode 845/1000...
#   Episode 845 ended at step 500 (terminated: False, truncated: True).
# Starting episode 846/1000...
#   Episode 846 ended at step 500 (terminated: False, truncated: True).
# Starting episode 847/1000...
#   Episode 847 ended at step 500 (terminated: False, truncated: True).
# Starting episode 848/1000...
#   Episode 848 ended at step 500 (terminated: False, truncated: True).
# Starting episode 849/1000...
#   Episode 849 ended at step 500 (terminated: False, truncated: True).
# Starting episode 850/1000...
#   Episode 850 ended at step 500 (terminated: False, truncated: True).
# Starting episode 851/1000...
#   Episode 851 ended at step 500 (terminated: False, truncated: True).
# Starting episode 852/1000...
#   Episode 852 ended at step 500 (terminated: False, truncated: True).
# Starting episode 853/1000...
#   Episode 853 ended at step 500 (terminated: False, truncated: True).
# Starting episode 854/1000...
#   Episode 854 ended at step 500 (terminated: False, truncated: True).
# Starting episode 855/1000...
#   Episode 855 ended at step 500 (terminated: False, truncated: True).
# Starting episode 856/1000...
#   Episode 856 ended at step 500 (terminated: False, truncated: True).
# Starting episode 857/1000...
#   Episode 857 ended at step 500 (terminated: False, truncated: True).
# Starting episode 858/1000...
#   Episode 858 ended at step 500 (terminated: False, truncated: True).
# Starting episode 859/1000...
#   Episode 859 ended at step 500 (terminated: False, truncated: True).
# Starting episode 860/1000...
#   Episode 860 ended at step 500 (terminated: False, truncated: True).
# Starting episode 861/1000...
#   Episode 861 ended at step 500 (terminated: False, truncated: True).
# Starting episode 862/1000...
#   Episode 862 ended at step 500 (terminated: False, truncated: True).
# Starting episode 863/1000...
#   Episode 863 ended at step 500 (terminated: False, truncated: True).
# Starting episode 864/1000...
#   Episode 864 ended at step 500 (terminated: False, truncated: True).
# Starting episode 865/1000...
#   Episode 865 ended at step 500 (terminated: False, truncated: True).
# Starting episode 866/1000...
#   Episode 866 ended at step 500 (terminated: False, truncated: True).
# Starting episode 867/1000...
#   Episode 867 ended at step 500 (terminated: False, truncated: True).
# Starting episode 868/1000...
#   Episode 868 ended at step 500 (terminated: False, truncated: True).
# Starting episode 869/1000...
#   Episode 869 ended at step 500 (terminated: False, truncated: True).
# Starting episode 870/1000...
#   Episode 870 ended at step 500 (terminated: False, truncated: True).
# Starting episode 871/1000...
#   Episode 871 ended at step 500 (terminated: False, truncated: True).
# Starting episode 872/1000...
#   Episode 872 ended at step 500 (terminated: False, truncated: True).
# Starting episode 873/1000...
#   Episode 873 ended at step 500 (terminated: False, truncated: True).
# Starting episode 874/1000...
#   Episode 874 ended at step 500 (terminated: False, truncated: True).
# Starting episode 875/1000...
#   Episode 875 ended at step 500 (terminated: False, truncated: True).
# Starting episode 876/1000...
#   Episode 876 ended at step 500 (terminated: False, truncated: True).
# Starting episode 877/1000...
#   Episode 877 ended at step 500 (terminated: False, truncated: True).
# Starting episode 878/1000...
#   Episode 878 ended at step 500 (terminated: False, truncated: True).
# Starting episode 879/1000...
#   Episode 879 ended at step 500 (terminated: False, truncated: True).
# Starting episode 880/1000...
#   Episode 880 ended at step 500 (terminated: False, truncated: True).
# Starting episode 881/1000...
#   Episode 881 ended at step 500 (terminated: False, truncated: True).
# Starting episode 882/1000...
#   Episode 882 ended at step 500 (terminated: False, truncated: True).
# Starting episode 883/1000...
#   Episode 883 ended at step 500 (terminated: False, truncated: True).
# Starting episode 884/1000...
#   Episode 884 ended at step 500 (terminated: False, truncated: True).
# Starting episode 885/1000...
#   Episode 885 ended at step 500 (terminated: False, truncated: True).
# Starting episode 886/1000...
#   Episode 886 ended at step 500 (terminated: False, truncated: True).
# Starting episode 887/1000...
#   Episode 887 ended at step 500 (terminated: False, truncated: True).
# Starting episode 888/1000...
#   Episode 888 ended at step 500 (terminated: False, truncated: True).
# Starting episode 889/1000...
#   Episode 889 ended at step 500 (terminated: False, truncated: True).
# Starting episode 890/1000...
#   Episode 890 ended at step 500 (terminated: False, truncated: True).
# Starting episode 891/1000...
#   Episode 891 ended at step 500 (terminated: False, truncated: True).
# Starting episode 892/1000...
#   Episode 892 ended at step 500 (terminated: False, truncated: True).
# Starting episode 893/1000...
#   Episode 893 ended at step 500 (terminated: False, truncated: True).
# Starting episode 894/1000...
#   Episode 894 ended at step 500 (terminated: False, truncated: True).
# Starting episode 895/1000...
#   Episode 895 ended at step 500 (terminated: False, truncated: True).
# Starting episode 896/1000...
#   Episode 896 ended at step 500 (terminated: False, truncated: True).
# Starting episode 897/1000...
#   Episode 897 ended at step 500 (terminated: False, truncated: True).
# Starting episode 898/1000...
#   Episode 898 ended at step 500 (terminated: False, truncated: True).
# Starting episode 899/1000...
#   Episode 899 ended at step 500 (terminated: False, truncated: True).
# Starting episode 900/1000...
#   Episode 900 ended at step 500 (terminated: False, truncated: True).
# Starting episode 901/1000...
#   Episode 901 ended at step 500 (terminated: False, truncated: True).
# Starting episode 902/1000...
#   Episode 902 ended at step 500 (terminated: False, truncated: True).
# Starting episode 903/1000...
#   Episode 903 ended at step 500 (terminated: False, truncated: True).
# Starting episode 904/1000...
#   Episode 904 ended at step 500 (terminated: False, truncated: True).
# Starting episode 905/1000...
#   Episode 905 ended at step 500 (terminated: False, truncated: True).
# Starting episode 906/1000...
#   Episode 906 ended at step 500 (terminated: False, truncated: True).
# Starting episode 907/1000...
#   Episode 907 ended at step 500 (terminated: False, truncated: True).
# Starting episode 908/1000...
#   Episode 908 ended at step 500 (terminated: False, truncated: True).
# Starting episode 909/1000...
#   Episode 909 ended at step 500 (terminated: False, truncated: True).
# Starting episode 910/1000...
#   Episode 910 ended at step 500 (terminated: False, truncated: True).
# Starting episode 911/1000...
#   Episode 911 ended at step 500 (terminated: False, truncated: True).
# Starting episode 912/1000...
#   Episode 912 ended at step 500 (terminated: False, truncated: True).
# Starting episode 913/1000...
#   Episode 913 ended at step 500 (terminated: False, truncated: True).
# Starting episode 914/1000...
#   Episode 914 ended at step 500 (terminated: False, truncated: True).
# Starting episode 915/1000...
#   Episode 915 ended at step 500 (terminated: False, truncated: True).
# Starting episode 916/1000...
#   Episode 916 ended at step 500 (terminated: False, truncated: True).
# Starting episode 917/1000...
#   Episode 917 ended at step 500 (terminated: False, truncated: True).
# Starting episode 918/1000...
#   Episode 918 ended at step 500 (terminated: False, truncated: True).
# Starting episode 919/1000...
#   Episode 919 ended at step 500 (terminated: False, truncated: True).
# Starting episode 920/1000...
#   Episode 920 ended at step 500 (terminated: False, truncated: True).
# Starting episode 921/1000...
#   Episode 921 ended at step 500 (terminated: False, truncated: True).
# Starting episode 922/1000...
#   Episode 922 ended at step 500 (terminated: False, truncated: True).
# Starting episode 923/1000...
#   Episode 923 ended at step 500 (terminated: False, truncated: True).
# Starting episode 924/1000...
#   Episode 924 ended at step 500 (terminated: False, truncated: True).
# Starting episode 925/1000...
#   Episode 925 ended at step 500 (terminated: False, truncated: True).
# Starting episode 926/1000...
#   Episode 926 ended at step 500 (terminated: False, truncated: True).
# Starting episode 927/1000...
#   Episode 927 ended at step 500 (terminated: False, truncated: True).
# Starting episode 928/1000...
#   Episode 928 ended at step 500 (terminated: False, truncated: True).
# Starting episode 929/1000...
#   Episode 929 ended at step 500 (terminated: False, truncated: True).
# Starting episode 930/1000...
#   Episode 930 ended at step 500 (terminated: False, truncated: True).
# Starting episode 931/1000...
#   Episode 931 ended at step 500 (terminated: False, truncated: True).
# Starting episode 932/1000...
#   Episode 932 ended at step 500 (terminated: False, truncated: True).
# Starting episode 933/1000...
#   Episode 933 ended at step 500 (terminated: False, truncated: True).
# Starting episode 934/1000...
#   Episode 934 ended at step 500 (terminated: False, truncated: True).
# Starting episode 935/1000...
#   Episode 935 ended at step 500 (terminated: False, truncated: True).
# Starting episode 936/1000...
#   Episode 936 ended at step 500 (terminated: False, truncated: True).
# Starting episode 937/1000...
#   Episode 937 ended at step 500 (terminated: False, truncated: True).
# Starting episode 938/1000...
#   Episode 938 ended at step 500 (terminated: False, truncated: True).
# Starting episode 939/1000...
#   Episode 939 ended at step 500 (terminated: False, truncated: True).
# Starting episode 940/1000...
#   Episode 940 ended at step 500 (terminated: False, truncated: True).
# Starting episode 941/1000...
#   Episode 941 ended at step 500 (terminated: False, truncated: True).
# Starting episode 942/1000...
#   Episode 942 ended at step 500 (terminated: False, truncated: True).
# Starting episode 943/1000...
#   Episode 943 ended at step 500 (terminated: False, truncated: True).
# Starting episode 944/1000...
#   Episode 944 ended at step 500 (terminated: False, truncated: True).
# Starting episode 945/1000...
#   Episode 945 ended at step 500 (terminated: False, truncated: True).
# Starting episode 946/1000...
#   Episode 946 ended at step 500 (terminated: False, truncated: True).
# Starting episode 947/1000...
#   Episode 947 ended at step 500 (terminated: False, truncated: True).
# Starting episode 948/1000...
#   Episode 948 ended at step 500 (terminated: False, truncated: True).
# Starting episode 949/1000...
#   Episode 949 ended at step 500 (terminated: False, truncated: True).
# Starting episode 950/1000...
#   Episode 950 ended at step 500 (terminated: False, truncated: True).
# Starting episode 951/1000...
#   Episode 951 ended at step 500 (terminated: False, truncated: True).
# Starting episode 952/1000...
#   Episode 952 ended at step 500 (terminated: False, truncated: True).
# Starting episode 953/1000...
#   Episode 953 ended at step 500 (terminated: False, truncated: True).
# Starting episode 954/1000...
#   Episode 954 ended at step 500 (terminated: False, truncated: True).
# Starting episode 955/1000...
#   Episode 955 ended at step 500 (terminated: False, truncated: True).
# Starting episode 956/1000...
#   Episode 956 ended at step 500 (terminated: False, truncated: True).
# Starting episode 957/1000...
#   Episode 957 ended at step 500 (terminated: False, truncated: True).
# Starting episode 958/1000...
#   Episode 958 ended at step 500 (terminated: False, truncated: True).
# Starting episode 959/1000...
#   Episode 959 ended at step 500 (terminated: False, truncated: True).
# Starting episode 960/1000...
#   Episode 960 ended at step 500 (terminated: False, truncated: True).
# Starting episode 961/1000...
#   Episode 961 ended at step 500 (terminated: False, truncated: True).
# Starting episode 962/1000...
#   Episode 962 ended at step 500 (terminated: False, truncated: True).
# Starting episode 963/1000...
#   Episode 963 ended at step 500 (terminated: False, truncated: True).
# Starting episode 964/1000...
#   Episode 964 ended at step 500 (terminated: False, truncated: True).
# Starting episode 965/1000...
#   Episode 965 ended at step 500 (terminated: False, truncated: True).
# Starting episode 966/1000...
#   Episode 966 ended at step 500 (terminated: False, truncated: True).
# Starting episode 967/1000...
#   Episode 967 ended at step 500 (terminated: False, truncated: True).
# Starting episode 968/1000...
#   Episode 968 ended at step 500 (terminated: False, truncated: True).
# Starting episode 969/1000...
#   Episode 969 ended at step 500 (terminated: False, truncated: True).
# Starting episode 970/1000...
#   Episode 970 ended at step 500 (terminated: False, truncated: True).
# Starting episode 971/1000...
#   Episode 971 ended at step 500 (terminated: False, truncated: True).
# Starting episode 972/1000...
#   Episode 972 ended at step 500 (terminated: False, truncated: True).
# Starting episode 973/1000...
#   Episode 973 ended at step 500 (terminated: False, truncated: True).
# Starting episode 974/1000...
#   Episode 974 ended at step 500 (terminated: False, truncated: True).
# Starting episode 975/1000...
#   Episode 975 ended at step 500 (terminated: False, truncated: True).
# Starting episode 976/1000...
#   Episode 976 ended at step 500 (terminated: False, truncated: True).
# Starting episode 977/1000...
#   Episode 977 ended at step 500 (terminated: False, truncated: True).
# Starting episode 978/1000...
#   Episode 978 ended at step 500 (terminated: False, truncated: True).
# Starting episode 979/1000...
#   Episode 979 ended at step 500 (terminated: False, truncated: True).
# Starting episode 980/1000...
#   Episode 980 ended at step 500 (terminated: False, truncated: True).
# Starting episode 981/1000...
#   Episode 981 ended at step 500 (terminated: False, truncated: True).
# Starting episode 982/1000...
#   Episode 982 ended at step 500 (terminated: False, truncated: True).
# Starting episode 983/1000...
#   Episode 983 ended at step 500 (terminated: False, truncated: True).
# Starting episode 984/1000...
#   Episode 984 ended at step 500 (terminated: False, truncated: True).
# Starting episode 985/1000...
#   Episode 985 ended at step 500 (terminated: False, truncated: True).
# Starting episode 986/1000...
#   Episode 986 ended at step 500 (terminated: False, truncated: True).
# Starting episode 987/1000...
#   Episode 987 ended at step 500 (terminated: False, truncated: True).
# Starting episode 988/1000...
#   Episode 988 ended at step 500 (terminated: False, truncated: True).
# Starting episode 989/1000...
#   Episode 989 ended at step 500 (terminated: False, truncated: True).
# Starting episode 990/1000...
#   Episode 990 ended at step 500 (terminated: False, truncated: True).
# Starting episode 991/1000...
#   Episode 991 ended at step 500 (terminated: False, truncated: True).
# Starting episode 992/1000...
#   Episode 992 ended at step 500 (terminated: False, truncated: True).
# Starting episode 993/1000...
#   Episode 993 ended at step 500 (terminated: False, truncated: True).
# Starting episode 994/1000...
#   Episode 994 ended at step 500 (terminated: False, truncated: True).
# Starting episode 995/1000...
#   Episode 995 ended at step 500 (terminated: False, truncated: True).
# Starting episode 996/1000...
#   Episode 996 ended at step 500 (terminated: False, truncated: True).
# Starting episode 997/1000...
#   Episode 997 ended at step 500 (terminated: False, truncated: True).
# Starting episode 998/1000...
#   Episode 998 ended at step 500 (terminated: False, truncated: True).
# Starting episode 999/1000...
#   Episode 999 ended at step 500 (terminated: False, truncated: True).
# Starting episode 1000/1000...
#   Episode 1000 ended at step 500 (terminated: False, truncated: True).
# Finished collecting imitator trajectories.
# 500000

# %%
naive_sqil_episode_rewards = defaultdict(float)
for rec in naive_sqil_returns:
    ep = rec['episode']
    naive_sqil_episode_rewards[ep] += float(rec['reward'])

naive_sqil_rewards = [naive_sqil_episode_rewards[e] for e in range(num_eval_eps)]
sum(naive_sqil_rewards) / num_eval_eps
# Out:
# -237.19039336882975

# %%
SAVE_DIR = '/home/et2842/causal/causalrl/models'
os.makedirs(SAVE_DIR, exist_ok=True)

MODEL_PATH = os.path.join(SAVE_DIR, 'nsqil_antlarge_h500_s445.pt')

ckpt = {
    'state_dict': actor.state_dict(),
    'z_dim': naive_z_dim,
    'action_dim': action_dim,
    'hidden_size_actor': hidden_dim,
    'num_blocks_actor': num_blocks_actor,
    'dropout_actor': dropout_actor,
    'layernorm_actor': layernorm_actor,
    'final_tanh': True,
    'action_bounds_low': eval_env.env.action_space.low,
    'action_bounds_high': eval_env.env.action_space.high,
    'Z_sets': naive_Z_trim,
    'dims': dims,
    'lookback': lookback,
}

torch.save(ckpt, MODEL_PATH)
print(f'Saved to: {MODEL_PATH}')
# Out:
# Saved to: /home/et2842/causal/causalrl/models/nsqil_antlarge_h500_s445.pt

# %%
mean_reward = np.mean(naive_sqil_rewards)
std_reward = np.std(naive_sqil_rewards)

print(f"E[Y]          = {mean_reward:.4f}")
print(f"Std[Y]        = {std_reward:.4f}")
print(f"E[Y] ± Std[Y] = {mean_reward:.4f} ± {std_reward:.4f}")
# Out:
# E[Y]          = -237.1904
# Std[Y]        = 104.6486
# E[Y] ± Std[Y] = -237.1904 ± 104.6486

# %%
# success rate: % of episodes solved in under 1000 steps
ep_lengths = defaultdict(int)
for rec in naive_sqil_returns:
    ep_lengths[rec['episode']] += 1

lengths = np.array([ep_lengths[e] for e in range(num_eval_eps)])
successes = lengths < num_steps
success_rate = successes.mean()
se = np.sqrt(success_rate * (1 - success_rate) / num_eval_eps)

print(f"Success rate   = {100 * success_rate:.2f}% ({successes.sum()}/{num_eval_eps} episodes)")
print(f"Std error      = {100 * se:.2f}%")
# Out:
# Success rate   = 0.00% (0/1000 episodes)
# Std error      = 0.00%

# %%
# successful episode lengths
success_lengths = lengths[successes]

if len(success_lengths) > 0:
    print(f"Successful episode lengths (n={len(success_lengths)}):")
    print(f"  Mean   = {np.mean(success_lengths):.2f}")
    print(f"  Std    = {np.std(success_lengths):.2f}")
    print(f"  Median = {np.median(success_lengths):.0f}")
    print(f"  Min    = {np.min(success_lengths)}")
    print(f"  Max    = {np.max(success_lengths)}")
    print(f"  25th%  = {np.percentile(success_lengths, 25):.0f}")
    print(f"  75th%  = {np.percentile(success_lengths, 75):.0f}")
else:
    print("No episodes were solved.")
# Out:
# No episodes were solved.
