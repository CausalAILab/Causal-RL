# %%
import causal_gym.envs.mujoco_envs as envs                          # runs the register() calls
import gymnasium as gym

env = gym.make("AdroitDoorMasked-v1", mask=[1]*28)
print(env.action_space, env.observation_space)
# → Box(-1.0, 1.0, (28,), float32)  Box(-inf, inf, (39,), float32)
# Out:
# Registering AdroitDoorMasked-v1
# Initializing AdroitDoorEnvMasked
# Box(-1.0, 1.0, (28,), float32) Box(-inf, inf, (39,), float32)
